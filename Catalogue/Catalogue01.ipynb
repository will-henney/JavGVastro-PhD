# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import os
import itertools
from scipy import stats
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from scipy.stats import linregress

# %%
plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="21"

# %% [markdown]
# SF list

# %%
#ComSam='list'
#ComSamI=pd.read_csv(ComSam+'.csv',header=None)
#ComSamI

# %% [markdown]
# 50
#
# http://articles.adsabs.harvard.edu//full/1951ZA.....30...17V/0000045.000.html
#
# http://articles.adsabs.harvard.edu//full/1958RvMP...30.1035M/0001037.000.html
#
# 60
#
# http://articles.adsabs.harvard.edu//full/1961MNRAS.122....1F/0000012.000.html
#
# 80
#
# http://articles.adsabs.harvard.edu//full/1985ApJ...288..142R/0000146.000.html *
#
# http://articles.adsabs.harvard.edu//full/1987ApJ...317..686O/0000688.000.html
#
# http://articles.adsabs.harvard.edu//full/1988ApJS...67...93C/0000122.000.html
#
# 90
#
# http://articles.adsabs.harvard.edu//full/1995ApJ...454..316M/0000324.000.html *
#
# https://iopscience.iop.org/article/10.1086/304573/fulltext/33796.text.html#fg4
#
# https://ui.adsabs.harvard.edu/abs/1999intu.conf..154J/abstract ***
#
# 00
#
#
# https://iopscience.iop.org/article/10.1088/0004-637X/700/2/1847#apj311588f19
#
# 10
#
#
# https://academic.oup.com/mnras/article/413/2/721/1062900
#
# https://academic.oup.com/mnras/article/463/3/2864/2646581
#
#
#
#
#
#
# \*revisar región
#
# \*\*agregar
#
# \*\*\*encontrar

# %% [markdown]
# Regiones HII

# %%
Sample='HII'

samples=pd.read_csv('DT//'+Sample+'.csv',header=None)

DataNH=dict()
DataH=dict()

#marker=itertools.cycle(('o','o','o','+','+','+','+','+','+','o','o','o','o','o','o',
#                        'x','x','o','x','o','o','o','o'))

marker=itertools.cycle((r"$a$",r"$a$",r"$b$",r"$c$",r"$e$",r"$e$",r"$e$",r"$e$",r"$e$",r"$e$",r"$f$",r"$f$",r"$f$",r"$f$",r"$f$",r"$f$",
                        r"$g$",r"$h$",r"$h$",r"$h$",r"$i$",r"$i$",r"$i$",r"$i$"))

color=itertools.cycle(("magenta","magenta","red","purple","black","black","black","black","black","black","blue","blue","blue","blue","blue","blue",
                       "darkred","green","green","green","orange","orange","orange","orange"))

for i in range(len(samples)):
    DataNH[i]=samples[0][i]
    
for i in range(len(samples)):
    DataH[i]=pd.read_csv('Data//'+DataNH[i]+'.csv')    
    
fig, ax=plt.subplots(figsize=(8,8))

    
for i in range(len(samples)):
    plt.loglog(DataH[i].pc,DataH[i].S,marker=next(marker),color=next(color), alpha=0.75, markersize=10)
    
ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.tick_params(which='both', labelright=False, direction='in', right=True,  top=True)
plt.grid(which='minor')

plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="21"
    
samples
# Out:
#                   0
# 0      1951VHOrion1
# 1      1951VHOrion2
# 2      1958MchOrion
# 3    1985RyJcsSh142
# 4    1987OdCast1499
# 5    1987OdCast6514
# 6   1987OdCast6523A
# 7   1987OdCast6523B
# 8    1987OdCast7000
# 9    1987OdCastS252
# 10  1988CastOrion1a
# 11  1988CastOrion1b
# 12  1988CastOrion1c
# 13  1988CastOrion2a
# 14  1988CastOrion2b
# 15  1988CastOrion2c
# 16       1995MDS170
# 17      1999JncsM17
# 18    1999JncsOrion
# 19     1999JncsS142
# 20   2016ArthOrionH
# 21   2016ArthOrionN
# 22   2016ArthOrionO
# 23   2016ArthOrionS

# %% [markdown]
# Orion

# %%
Sample='orion'

samples=pd.read_csv('DT//'+Sample+'.csv',header=None)

DataNO=dict()
DataO=dict()

marker=itertools.cycle(('*','*','o','^','^','^','^','^','^','*','o'))
color=itertools.cycle(("red","red","blue","black","black","black","black","black","black","magenta",
                       "limegreen","limegreen","red","red","red","red"))

for i in range(len(samples)):
    DataNO[i]=samples[0][i]
    
for i in range(len(samples)):
    DataO[i]=pd.read_csv('Data//'+DataNO[i]+'.csv')    

fig, ax=plt.subplots(figsize=(8,8))

    
for i in range(len(samples)):
    plt.loglog(DataO[i].pc,DataO[i].S,marker=next(marker),color=next(color),alpha=0.75)
    
ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.tick_params(which='both', labelright=False, direction='in', right=True,  top=True)
plt.grid(which='minor')

plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="21"

samples
# Out:
#                   0
# 0      1951VHOrion1
# 1      1951VHOrion2
# 2      1958MchOrion
# 3   1988CastOrion1a
# 4   1988CastOrion1b
# 5   1988CastOrion1c
# 6   1988CastOrion2a
# 7   1988CastOrion2b
# 8   1988CastOrion2c
# 9     1999JncsOrion
# 10   2016ArthOrionH
# 11   2016ArthOrionN
# 12   2016ArthOrionO
# 13   2016ArthOrionS

# %% [markdown]
# GEHR

# %%
Sample='GHRx'

samples=pd.read_csv('DT//'+Sample+'.csv',header=None)

DataNG=dict()
DataG=dict()

marker=itertools.cycle((r"$e$",r"$a$",r"$c$",r"$c$",r"$c$",r"$d$",r"$d$",r"$d$",r"$b$",r"$b$"))
#marker=itertools.cycle(('*','o','^','^','^','^','^','^','*','o'))
color=itertools.cycle(("red","black","blue","green","blue","magenta","magenta","magenta",
                       "limegreen","limegreen","red","red","red","red"))

for i in range(len(samples)):
    DataNG[i]=samples[0][i]
    
for i in range(len(samples)):
    DataG[i]=pd.read_csv('Data//'+DataNG[i]+'.csv')    

fig, ax=plt.subplots(figsize=(8,8))

    
for i in range(len(samples)):
    plt.loglog(DataG[i].pc,DataG[i].S,marker=next(marker),color=next(color),alpha=0.75, markersize=10)
    
ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.tick_params(which='both', labelright=False, direction='in', right=True,  top=True)
plt.grid(which='minor')

plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="21"

samples
# Out:
#               0
# 0  1961Fst30Dor
# 1     1997MT604
# 2  2009Lagr595H
# 3  2009Lagr595O
# 4  2009Lagr595S
# 5  2011Lagr595H
# 6  2011Lagr595O
# 7  2011Lagr595S
# 8   2019Mk30Dor
# 9     2019Mk604

# %% [markdown]
# GHR + TESIS

# %%
Sample='GHR'

samples=pd.read_csv('DT//'+Sample+'.csv',header=None)

DataN=dict()
Data=dict()

marker=itertools.cycle(('x','x','x','x','x','x','x','x','x','o','o','o','o','o','o','o','o','o','o'))
color=itertools.cycle(("black","black","black","black","black","black","black","black","black",
                       "limegreen","limegreen","limegreen","limegreen","limegreen"
                       ,"limegreen","limegreen","limegreen","limegreen","limegreen"))
alpha=itertools.cycle((0.5,0.5,0.5,0.5,0.5,0.5,0.5,
                       0.5,0.5,0.75,0.75,0.75,0.75))

for i in range(len(samples)):
    DataN[i]=samples[0][i]
    
for i in range(len(samples)):
    Data[i]=pd.read_csv('Data//'+DataN[i]+'.csv')    

fig, ax=plt.subplots(figsize=(8,8))

    
for i in range(len(samples)):
    plt.loglog(Data[i].pc,Data[i].S,marker=next(marker),color=next(color),alpha=next(alpha))
    
ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.tick_params(which='both', labelright=False, direction='in', right=True,  top=True)
plt.grid(which='minor')

plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="21"

samples
# Out:
#                 0
# 0       1997MT604
# 1    2009Lagr595H
# 2    2009Lagr595O
# 3    2009Lagr595S
# 4    2011Lagr595H
# 5    2011Lagr595O
# 6    2011Lagr595S
# 7     2019Mk30Dor
# 8       2019Mk604
# 9   2021JGV604IHA
# 10  2021JGV604IHB
# 11  2021JGV604IHC
# 12  2021JGV604THB
# 13  2021JGV604INB
# 14  2021JGV604INC
# 15  2021JGV604ISB
# 16  2021JGV604ISC
# 17  2021JGV604IOB
# 18  2021JGV604IOC
# 19  2021JGV604TOB

# %%
#plt.scatter(Data[1].pc,Data[1].S)
#plt.loglog(Data[1].pc,Data[1].S)
#plt.scatter(Data[2].pc,Data[2].S)
#plt.loglog(Data[2].pc,Data[2].S)
#plt.scatter(Data[3].pc,Data[3].S)
#plt.loglog(Data[3].pc,Data[3].S)

# %%
#xxx

# %% [markdown]
# Tesis

# %%
Sample='tesis'

samples=pd.read_csv('DT//'+Sample+'.csv',header=None)

DataNx=dict()
Datax=dict()

marker=itertools.cycle(('o','^','^','^','^','^','^','*','o','o','o','o','.'))
color=itertools.cycle(("black","blue","green","blue","magenta","magenta","magenta",
                       "limegreen","limegreen","red","red","red","red"))

for i in range(len(samples)):
    DataNx[i]=samples[0][i]
    
for i in range(len(samples)):
    Datax[i]=pd.read_csv('Data//'+DataNx[i]+'.csv')    

fig, ax=plt.subplots(figsize=(8,8))

    
for i in range(len(samples)):
    plt.loglog(Datax[i].pc,Datax[i].S,marker=next(marker),color=next(color),alpha=0.75)
    
ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.tick_params(which='both', labelright=False, direction='in', right=True,  top=True)
plt.grid(which='minor')

plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="21"

samples
# Out:
#                 0
# 0   2021JGV604IHA
# 1   2021JGV604IHB
# 2   2021JGV604IHC
# 3   2021JGV604THB
# 4   2021JGV604INB
# 5   2021JGV604INC
# 6   2021JGV604ISB
# 7   2021JGV604ISC
# 8   2021JGV604IOB
# 9   2021JGV604IOC
# 10  2021JGV604TOB

# %% [markdown]
# Future

# %%
Sample='FutGHR'

samples=pd.read_csv('DT//'+Sample+'.csv',header=None)

DataNxx=dict()
Dataxx=dict()

marker=itertools.cycle(('o','x','+','^','.','v'))
color=itertools.cycle(("black","blue","red","magenta","indigo","limegreen"))

for i in range(len(samples)):
    DataNxx[i]=samples[0][i]
    
for i in range(len(samples)):
    Dataxx[i]=pd.read_csv('Data//'+DataNxx[i]+'.csv')    

fig, ax=plt.subplots(figsize=(8,8))

    
for i in range(len(samples)):
    plt.loglog(Dataxx[i].pc,Dataxx[i].S,marker=next(marker),color=next(color),alpha=0.75)
    
ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.tick_params(which='both', labelright=False, direction='in', right=True,  top=True)
plt.grid(which='minor')

plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="21"

samples
# Out:
#             0
# 0     30DorXH
# 1      HVTAUH
# 2      HXTAUH
# 3  M42HaenelH
# 4        M8XH
# 5     N3372XH

# %% [markdown]
# GHR + HII + Tesis

# %%
Sample='All'

samples=pd.read_csv('DT//'+Sample+'.csv',header=None)

DataN=dict()
Data=dict()

#marker=itertools.cycle(('o','^','^','^','*','o'))
#color=itertools.cycle(("black","magenta","magenta","magenta","limegreen","limegreen"))

for i in range(len(samples)):
    DataN[i]=samples[0][i]
    
for i in range(len(samples)):
    Data[i]=pd.read_csv('Data//'+DataN[i]+'.csv')    

fig, ax=plt.subplots(figsize=(8,8))

    
for i in range(len(samples)):
    plt.scatter(Data[i].pc,Data[i].S)
 
ax.set(xscale='log',yscale='log')
ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.tick_params(which='both', labelright=False, direction='in', right=True,  top=True)
plt.grid(which='minor')

plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="21"

samples
# Out:
#                   0
# 0      1951VHOrion1
# 1      1951VHOrion2
# 2      1958MchOrion
# 3      1961Fst30Dor
# 4    1985RyJcsSh142
# 5    1987OdCast1499
# 6    1987OdCast6514
# 7   1987OdCast6523A
# 8   1987OdCast6523B
# 9    1987OdCast7000
# 10   1987OdCastS252
# 11  1988CastOrion1a
# 12  1988CastOrion1b
# 13  1988CastOrion1c
# 14  1988CastOrion2a
# 15  1988CastOrion2b
# 16  1988CastOrion2c
# 17       1995MDS170
# 18        1997MT604
# 19      1999JncsM17
# 20    1999JncsOrion
# 21     1999JncsS142
# 22     2009Lagr595H
# 23     2009Lagr595O
# 24     2009Lagr595S
# 25     2011Lagr595H
# 26     2011Lagr595O
# 27     2011Lagr595S
# 28   2016ArthOrionH
# 29   2016ArthOrionN
# 30   2016ArthOrionO
# 31   2016ArthOrionS
# 32      2019Mk30Dor
# 33        2019Mk604
# 34    2021JGV604IHA
# 35    2021JGV604IHB
# 36    2021JGV604IHC
# 37    2021JGV604THB

# %%
resultx = pd.concat(Datax)
yx=np.log10(resultx.S)
xx=np.log10(resultx.pc)

# %%
resulth = pd.concat(DataH)
yh=np.log10(resulth.S)
xh=np.log10(resulth.pc)

# %%
result = pd.concat(Data)

# %%
nsample=len(result)
w=np.ones(nsample)

# %%
y=np.log10(result.S)
x=np.log10(result.pc)

# %%
#mod_wls = sm.WLS(y, x, weights=1./(w ** 2))
#res_wls = mod_wls.fit()
#print(res_wls.summary())

# %%
X = sm.add_constant(x)
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      S   R-squared:                       0.362
# Model:                            OLS   Adj. R-squared:                  0.361
# Method:                 Least Squares   F-statistic:                     611.8
# Date:                Fri, 18 Dec 2020   Prob (F-statistic):          2.41e-107
# Time:                        06:22:22   Log-Likelihood:                -588.91
# No. Observations:                1080   AIC:                             1182.
# Df Residuals:                    1078   BIC:                             1192.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5761      0.014    115.579      0.000       1.549       1.603
# ...

# %%
results.params[0],results.params[1]
# Out:
# (1.5761443060339806, 0.20821484256954492)

# %%
intr=linregress(x, y)

# %%
intr.slope,intr.stderr,intr.intercept,intr.rvalue
# Out:
# (0.2082148425695449,
#  0.00841784076162379,
#  1.5761443060339813,
#  0.6017153155803503)

# %%
space=np.linspace(-2.75,2.5,100)
space2=np.linspace(-1,1,100)

# %%
fig,ax=plt.subplots(figsize=(8,8))

plt.scatter(x,y,marker='x')
plt.scatter(xx,yx,marker='.')
plt.scatter(xh,yh,marker='.')
plt.plot(space,(space*results.params[1])+results.params[0],color="red",label='α ='+str(round(results.params[1],3)))
plt.plot(space,(space*(2/3))+results.params[0],color="black",label='α =2/3')
plt.plot(space2,(space2*(5/3))+results.params[0],color="indigo",label='α =5/3')
ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.legend(loc='lower right')

# %%
#result.to_csv('test.csv')

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 42.88655710220337 seconds ---
