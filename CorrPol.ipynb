# %%
import time
start_time=time.time()

# %% [markdown]
# Abstract

# %% [markdown]
# Se presenta el análisis estadístico aplicado a la linea de Halfa para NGC 604. Se realizan y comparan 6 muestras. Las muestra orginal i, las muestras ii y iii que corresponde a regiones de menor tamaño y número de puntos. Cada muestra de velocidad se corrige con un ajuste polnomial.

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from SBRF import sosf,acf,ps,sosfnorm,sosfw,sosfw2,sosfs,sosfnorms,sfwh,pst
import os
import itertools


plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="15"

# %% [markdown]
# Input Data

# %%
#Input
#Constant
c=299792.459#km/s
#Iraf
corrhelio=25.68#km/s
#Theory Lambda
lr=[6562.8,6548,6583,6717,6731]#AngstromsR
#lb=[4861.36,4958.9,5006.9]#AngstromsB

# %% [markdown]
# Astronomical Observations

# %%
inputf='604.Isis.WHT.Red.txt'

data0=pd.read_table(inputf)
data1=data0.rename(columns={"Center":"Center.0","ErrC":"ErrC.0","Width":"Width.0","ErrW":"ErrW.0","Peak":"Peak.0","ErrP":"ErrP.0",})

# %%
#LimitData
min0=65
max0=145
mr=(data1.X<max0)&(data1.X>min0)
data1=data1[mr]

# %% [markdown]
# Emission lines data

# %%
for i in range(1):
    Nx=i
    N=str(Nx)

    data2=data1[['X','Y','Center.'+N,'Peak.'+N,'Width.'+N]]

    RVo=c*(data2["Center."+N]-lr[Nx])/lr[Nx]
    RV=RVo+corrhelio

    data2=data2.assign(RV=RV.values)

    a=[data2.X,data2.Y,data2.RV,data2['Peak.'+N]]
    data3=pd.DataFrame(a).T
    data3.columns=['X','Y','RV','I']
    data3.to_csv('dataI'+str(int(lr[Nx]))+'.csv')

# %% [markdown]
# # Muestra (i)

# %%
datap='dataI6562.csv'
dt=pd.read_csv(datap)
dt=dt.rename(columns={'Unnamed: 0':'No'})
dt=dt.drop('No',axis=1)
os.remove(datap)
dt.describe()
# Out:
#                 X           Y          RV             I
# count  600.000000  600.000000  600.000000    600.000000
# mean   105.269000    9.390000 -250.043594   2277.239467
# std     23.243169    6.256047   10.420092   3750.107456
# min     65.710000    0.000000 -277.593319     27.150000
# 25%     85.485000    4.000000 -257.836471    281.925000
# 50%    105.270000    9.000000 -249.888052   1017.500000
# 75%    125.045000   15.000000 -244.018098   2403.500000
# max    144.830000   19.600000 -205.463695  30960.000000

# %% [markdown]
# Statistical Data

# %%
sns.pairplot(dt, 
             vars=["I","RV"], 
             diag_kind='hist',  
             plot_kws=dict(alpha=0.3, s=10, edgecolor='none'),
             diag_kws=dict(bins=20),
            )
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# Emission Map

# %%
datal=dt.copy()
datal.I=np.log10(datal.I)
datal.X=datal.X.astype(int)
#datal.Y=datal.Y.astype(int)

dataH_f=(datal.round(2)).pivot(index='Y', columns='X', values='I')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataH_f, cmap="viridis",xticklabels='auto')
plt.gca().invert_yaxis()
plt.xticks(rotation='vertical')
plt.yticks(rotation='horizontal')


plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="16"

# %% [markdown]
# Radial Velocity

# %%
datal=dt.copy()
dataH_rv=(datal.round(2)).pivot(index='Y', columns='X', values='RV')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataH_rv, cmap="viridis")
plt.gca().invert_yaxis()
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# Weighted property

# %%
W=np.log(abs((dt.RV*dt.I)/dt.I.sum()))
W.head()
# Out:
# 0   -4.307465
# 1   -4.062174
# 2   -3.976022
# 3   -3.793160
# 4   -3.335217
# dtype: float64

# %%
dtW=[dt.X,dt.Y,W]
dtW=pd.DataFrame(dtW).T
dtW.columns=['X','Y','W']

dtH_W=(dtW.round(2)).pivot(index='Y', columns='X', values='W')
fig, ax = plt.subplots(figsize=(14, 3.3))
sns.heatmap(dtH_W, cmap="viridis")
plt.gca().invert_yaxis()

# %% [markdown]
# Statistical Analysis SBR

# %%
sfH00=sosf(dt)
sfnH00=sosfnorm(dt)
sfwH00=sosfw(dt)
sfw2H00=sosfw2(dt)
afH00=acf(dt)
sfhH00=sfwh(dt)
psH00=ps(dt)
pstH00=pst(dt)
# Out:
# /home/zalenovo/Dropbox/Cloud/codepycloud/PhD.Final/SBR.Final/SBRF.py:242: RuntimeWarning: divide by zero encountered in double_scalars
#   g=e/f
# /home/zalenovo/Dropbox/Cloud/codepycloud/PhD.Final/SBR.Final/SBRF.py:251: RuntimeWarning: divide by zero encountered in double_scalars
#   g=e/f
# /home/zalenovo/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:151: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims)
# /home/zalenovo/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:183: RuntimeWarning: invalid value encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True)
# /home/zalenovo/Dropbox/Cloud/codepycloud/PhD.Final/SBR.Final/SBRF.py:687: RuntimeWarning: divide by zero encountered in double_scalars
#   g=e/f
# /home/zalenovo/Dropbox/Cloud/codepycloud/PhD.Final/SBR.Final/SBRF.py:696: RuntimeWarning: divide by zero encountered in double_scalars
#   g=e/f
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 3))
scat = plt.scatter(dt.X, dt.RV, c=dt.Y, s=dt.I*0.1, alpha=0.6, cmap="coolwarm")
fig.colorbar(scat, ax=ax).set_label("Y")

# %%
marker=itertools.cycle((',','+','.','o','*'))

X=dict()
Y=dict()
XY=dict()

n=7

for i in range(n):
    X[i] = np.poly1d(np.polyfit(dt.X, dt.RV, i))

fig, ax = plt.subplots(figsize=(10, 3))
RAgrid = np.linspace(dt.X.min(), dt.X.max())

for i in range(n):
    ax.plot(RAgrid, X[i](RAgrid), label=[i+1], marker=next(marker))
    
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))

fig, ax = plt.subplots(figsize=(10, 3))
scat = plt.scatter(dt.X, dt.RV, c=dt.Y, s=dt.I*0.1, alpha=0.3, cmap="coolwarm")
fig.colorbar(scat, ax=ax).set_label("Y")

marker=itertools.cycle((',','+','.','o','*'))


for i in range(n):
    ax.plot(RAgrid, X[i](RAgrid), label=[i+1], marker=next(marker), c="k")

for i in range(n):
    Y[i]=dt.RV-X[i](dt.X)

for i in range(n):
    fig, ax=plt.subplots(figsize=(7,6))
    hist=dt.RV-dt.RV.mean()
    sns.distplot(hist,bins=40,rug=True)
    sns.distplot(Y[i],bins=40,rug=True)

XY=dict()

for i in range(n):
    XY[i]= pd.DataFrame({'X': dt.X, 'Y': dt.Y, 'RV':Y[i], 'I':dt.I})

for i in range(n):
    print(X[i])
# Out:
#
# -250
#
# -0.1871 x - 230.4
#            2
# 0.0005181 x - 0.2961 x - 224.9
#            3           2
# 4.633e-05 x - 0.01411 x + 1.199 x - 274.2
#            4            3         2
# 1.594e-05 x - 0.006664 x + 1.023 x - 68.51 x + 1442
#            5             4           3         2
# 5.687e-07 x - 0.0002834 x + 0.05534 x - 5.289 x + 247.1 x - 4757
#             6             5            4          3         2
# -1.018e-08 x + 6.999e-06 x - 0.001953 x + 0.2834 x - 22.56 x + 934.8 x - 1.599e+04

# %%
XY0=sosf(XY[0])
XY1=sosf(XY[1])
XY2=sosf(XY[2])
XY3=sosf(XY[3])
XY4=sosf(XY[4])
XY5=sosf(XY[5])
XY6=sosf(XY[6])
# Out:
# /home/zalenovo/Dropbox/Cloud/codepycloud/PhD.Final/SBR.Final/SBRF.py:242: RuntimeWarning: divide by zero encountered in double_scalars
#   g=e/f
# /home/zalenovo/Dropbox/Cloud/codepycloud/PhD.Final/SBR.Final/SBRF.py:251: RuntimeWarning: divide by zero encountered in double_scalars
#   g=e/f
# /home/zalenovo/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:151: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims)
# /home/zalenovo/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:183: RuntimeWarning: invalid value encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True)

# %%
fig, ax=plt.subplots(figsize=(7,6))
ax.errorbar(XY0['Lag'],XY0['Nmqvd'],xerr=XY0.ErrX, yerr=XY0.ErrY, fmt="o-",color='b', ecolor='b', alpha=0.5, markersize=7.5, label='ord 1')
ax.errorbar(XY1['Lag'],XY1['Nmqvd'],xerr=XY1.ErrX, yerr=XY1.ErrY, fmt="+-",color='k', ecolor='b', alpha=0.5, markersize=7.5, label='ord 2')
ax.errorbar(XY2['Lag'],XY2['Nmqvd'],xerr=XY2.ErrX, yerr=XY2.ErrY, fmt="^-",color='c', ecolor='b', alpha=0.5, markersize=7.5, label='ord 3')
ax.errorbar(XY3['Lag'],XY3['Nmqvd'],xerr=XY3.ErrX, yerr=XY3.ErrY, fmt="v-",color='y', ecolor='b', alpha=0.5, markersize=7.5, label='ord 4')
ax.errorbar(XY4['Lag'],XY4['Nmqvd'],xerr=XY4.ErrX, yerr=XY4.ErrY, fmt="+-",color='g', ecolor='b', alpha=0.5, markersize=7.5, label='ord 5')
ax.errorbar(XY5['Lag'],XY5['Nmqvd'],xerr=XY5.ErrX, yerr=XY5.ErrY, fmt="^-",color='r', ecolor='b', alpha=0.5, markersize=7.5, label='ord 6')
ax.errorbar(XY6['Lag'],XY6['Nmqvd'],xerr=XY6.ErrX, yerr=XY6.ErrY, fmt="v-",color='m', ecolor='b', alpha=0.5, markersize=7.5, label='ord 7')


ax.set(xscale='log',yscale='log')
#sgrid = np.logspace(.05, 1.25)
#ax.plot(sgrid, 0.5*sgrid**(2/3), color="k", lw=0.8, label='2/3')
#ax.axhline(y=2, color='k', linestyle$
ax.set(xlabel='lag [arcsec]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.title('Función de estructura, $S_{2}(l)$')
plt.tick_params(which='both', labelright=True, direction='in', right=True,  top=True)
plt.legend(loc='lower center')
plt.grid(which='minor')


plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="15"

# %%
fig, ax = plt.subplots(figsize=(5, 3))
scat = plt.scatter(dt.Y, dt.RV, c=dt.X, s=dt.I*0.03, alpha=0.6, cmap="gist_ncar", vmin=65.0, vmax=120)
fig.colorbar(scat, ax=ax).set_label("X")
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
marker=itertools.cycle((',','+','.','o','*'))

X=dict()
Y=dict()
XY=dict()

n=7

for i in range(n):
    X[i] = np.poly1d(np.polyfit(dt.Y, dt.RV, i))

fig, ax = plt.subplots(figsize=(10, 3))
Decgrid = np.linspace(dt.Y.min(), dt.Y.max())

for i in range(n):
    ax.plot(Decgrid, X[i](Decgrid), label=[i+1], marker=next(marker))
    
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))

fig, ax = plt.subplots(figsize=(5, 3))
scat = plt.scatter(dt.Y, dt.RV, c=dt.X, s=dt.I*0.1, alpha=0.3, cmap="gist_ncar")
fig.colorbar(scat, ax=ax).set_label("X")

marker=itertools.cycle((',','+','.','o','*'))


for i in range(n):
    ax.plot(Decgrid, X[i](Decgrid), label=[i+1], marker=next(marker), c="k")

for i in range(n):
    Y[i]=dt.RV-X[i](dt.Y)

for i in range(n):
    fig, ax=plt.subplots(figsize=(7,6))
    hist=dt.RV-dt.RV.mean()
    sns.distplot(hist,bins=40,rug=True)
    sns.distplot(Y[i],bins=40,rug=True)

XY=dict()

for i in range(n):
    XY[i]= pd.DataFrame({'X': dt.X, 'Y': dt.Y, 'RV':Y[i], 'I':dt.I})

for i in range(n):
    print(X[i])
# Out:
#
# -250
#
# -0.4515 x - 245.8
#          2
# 0.03189 x - 1.077 x - 244
#            3          2
# -0.008668 x + 0.2847 x - 2.928 x - 241.8
#            4           3          2
# 0.0008795 x - 0.04305 x + 0.7038 x - 4.56 x - 240.9
#            5            4            3          2
# 4.636e-05 x - 0.001387 x - 0.004431 x + 0.4377 x - 3.937 x - 241
#            6            5           4          3         2
# 2.326e-05 x - 0.001307 x + 0.02806 x - 0.2988 x + 1.757 x - 6.007 x - 240.8

# %%
XY0=sosf(XY[0])
XY1=sosf(XY[1])
XY2=sosf(XY[2])
XY3=sosf(XY[3])
XY4=sosf(XY[4])
XY5=sosf(XY[5])
XY6=sosf(XY[6])
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
fig, ax=plt.subplots(figsize=(7,6))
ax.errorbar(XY0['Lag'],XY0['Nmqvd'],xerr=XY0.ErrX, yerr=XY0.ErrY, fmt="o-",color='b', ecolor='b', alpha=0.5, markersize=7.5, label='ord 1')
ax.errorbar(XY1['Lag'],XY1['Nmqvd'],xerr=XY1.ErrX, yerr=XY1.ErrY, fmt="+-",color='k', ecolor='b', alpha=0.5, markersize=7.5, label='ord 2')
ax.errorbar(XY2['Lag'],XY2['Nmqvd'],xerr=XY2.ErrX, yerr=XY2.ErrY, fmt="^-",color='c', ecolor='b', alpha=0.5, markersize=7.5, label='ord 3')
ax.errorbar(XY3['Lag'],XY3['Nmqvd'],xerr=XY3.ErrX, yerr=XY3.ErrY, fmt="v-",color='y', ecolor='b', alpha=0.5, markersize=7.5, label='ord 4')
ax.errorbar(XY4['Lag'],XY4['Nmqvd'],xerr=XY4.ErrX, yerr=XY4.ErrY, fmt="+-",color='g', ecolor='b', alpha=0.5, markersize=7.5, label='ord 5')
ax.errorbar(XY5['Lag'],XY5['Nmqvd'],xerr=XY5.ErrX, yerr=XY5.ErrY, fmt="^-",color='r', ecolor='b', alpha=0.5, markersize=7.5, label='ord 6')
ax.errorbar(XY6['Lag'],XY6['Nmqvd'],xerr=XY6.ErrX, yerr=XY6.ErrY, fmt="v-",color='m', ecolor='b', alpha=0.5, markersize=7.5, label='ord 7')


ax.set(xscale='log',yscale='log')
#sgrid = np.logspace(.05, 1.25)
#ax.plot(sgrid, 0.5*sgrid**(2/3), color="k", lw=0.8, label='2/3')
#ax.axhline(y=2, color='k', linestyle$
ax.set(xlabel='lag [arcsec]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.title('Función de estructura, $S_{2}(l)$')
plt.tick_params(which='both', labelright=True, direction='in', right=True,  top=True)
plt.legend(loc='lower center')
plt.grid(which='minor')


plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="15"

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 102.28252267837524 seconds ---

# %%
#psH00.to_csv('datax.csv')
