# %%
import time
start_time=time.time()

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import lmfit

from bfunc import bfunc00,bfunc01,bfunc02

# %% [markdown]
# Data load and region parameters

# %%
data = json.load(open("SFdata//595.json"))

pixscale = 0.26 # arcsec
pixscale *= 4.09                   # parsec
s0 = 4.09/2.355                    # parsec
m = 1.5

# %%
r = pixscale * 10**np.array(data["log10 r"])
rgrid = pixscale * np.logspace(0.0, 2)

B = np.array(data["Unweighted B(r)"])

sig2 = data["Unweighted sigma^2"]
r0 = np.interp(sig2, B, r)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
# Plot fit to unweighted strucfunc
ax.plot(rgrid, bfunc02(rgrid, r0, sig2, m, s0, 1.5), color="red")
ax.plot(rgrid, bfunc00(rgrid, r0, sig2, m), color="0.8")
# Plot points from unweighted strucfunc
ax.plot(r, B, 'o',  color='black')

ax.axhline(sig2)
ax.axvline(2.355 * s0, linestyle="dashed")
ax.axvline(r0, linestyle="dotted")

ax.set(
    xscale = "log",
    yscale = "log",
    ylim  = [1, 250],
    xlim  = [1, 150],
    xlabel = "r [pc]",
    ylabel = r"B(r) [km$^{2}$/s$^{2}$]",
)

sig2
# Out:
# 44.12786785616313

# %%
model02 = lmfit.Model(bfunc02)
model02.param_names
# Out:
# ['r0', 'sig2', 'm', 's0', 'noise']

# %%
relative_uncertainty = 0.15
weights = 1.0 / (relative_uncertainty * B)
weights[-5:] /= 4.0

# %%
for p in model02.param_names:
    model02.set_param_hint(p, min=0.0)
model02.set_param_hint("sig2", value=sig2, vary=False)
model02.set_param_hint("s0", min=1.0)
model02.print_param_hints()
# Out:
# Name      Value      Min      Max     Vary    Expr
# m           nan        0      inf     True
# noise       nan        0      inf     True
# r0          nan        0      inf     True
# s0          nan        1      inf     True
# sig2    44.1279        0      inf    False

# %%
result2 = model02.fit(
    B, 
    weights=weights,
    r=r, r0=r0, m=m, s0=s0, noise=1.0,
)

# %%
fig, _ = result2.plot()
fig.axes[0].set(
    xscale="log",
    yscale="symlog",
)
fig.axes[1].set(
    xscale="log",
    yscale="log",
);

# %%
print(result2.fit_report())
# Out:
# [[Model]]
#     Model(bfunc02)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 58
#     # data points      = 16
#     # variables        = 4
#     chi-square         = 9.79098247
#     reduced chi-square = 0.81591521
#     Akaike info crit   = 0.14196933
#     Bayesian info crit = 3.23232422
# ##  Warning: uncertainties could not be estimated:
#     s0:     at boundary
# [[Variables]]
#     r0:     8.72944859 (init = 8.818012)
#     sig2:   44.12787 (fixed)
#     m:      1.78746470 (init = 1.5)
#     s0:     1.00000000 (init = 1.73673)
#     noise:  2.82279923 (init = 1)

# %%
for p in result2.model.param_names:
    result2.params[p].stderr = result2.params[p].value * 0.1

# %%
result2.conf_interval()
print(result2.ci_report())
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\lmfit\confidence.py:312: UserWarning: Bound reached with prob(s0=1.0) = 0.0 < max(sigmas)
#   warn(errmsg)
#           99.73%    95.45%    68.27%    _BEST_    68.27%    95.45%    99.73%
#  r0   :  -1.84130  -1.21128  -0.62001   8.72945  +0.74738  +1.81568  +3.73191
#  m    :  -0.58014  -0.36105  -0.17621   1.78746  +0.19236  +0.43625  +0.80356
#  s0   :      -inf      -inf      -inf   1.00000  +0.04598  +0.19196  +0.49354
#  noise:  -1.29818  -0.76390  -0.35530   2.82280  +0.35220  +0.74979  +1.25781

# %%
plt.style.use([
    "seaborn-poster",
])

# %%
plot_limits = {
    "s0": [0.0, 2.0],
    "m": [0.8, 3],
    "r0": [5.0, 16.0],
    "noise": [0.0, 6.0],
}

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

plt.title('NGC 595')
levels = [0.6827, 0.9545, 0.9973]
colors = ["g", "y", "r"]

for ax, [xvar, yvar] in zip(axes.flat, [
    ["s0", "noise"],
    ["r0", "m"],
    ["m", "s0"],
    ["r0", "s0"],
]):
    cx, cy, grid = lmfit.conf_interval2d(
        result2, result2, xvar, yvar, 30, 30,
        limits=[plot_limits[xvar], plot_limits[yvar]],
    )
    ctp = ax.contour(cx, cy, grid, levels, colors=colors)
    ax.set_xlabel(xvar)
    ax.set_ylabel(yvar)

fig.tight_layout();

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 17.061476707458496 seconds ---
