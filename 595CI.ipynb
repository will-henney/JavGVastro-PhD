# %%
import time
start_time=time.time()

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import lmfit

from bfunc import bfunc00,bfunc01,bfunc02

# %% [markdown]
# Data load and region parameters

# %%
data = json.load(open("SFdata//595.json"))

pixscale = 0.26 # arcsec
pixscale *= 4.09                   # parsec
s0 = 4.09/2.355                    # parsec
m = 1.5

# %%
r = pixscale * 10**np.array(data["log10 r"])
rgrid = pixscale * np.logspace(0.0, 2)

B = np.array(data["Unweighted B(r)"])

sig2 = data["Unweighted sigma^2"]
r0 = np.interp(sig2, B, r)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
# Plot fit to unweighted strucfunc
ax.plot(rgrid, bfunc02(rgrid, r0, sig2, m, s0, 1.5), color="red")
ax.plot(rgrid, bfunc00(rgrid, r0, sig2, m), color="0.8")
# Plot points from unweighted strucfunc
ax.plot(r, B, 'o',  color='black')

ax.axhline(sig2)
ax.axvline(2.355 * s0, linestyle="dashed")
ax.axvline(r0, linestyle="dotted")

ax.set(
    xscale = "log",
    yscale = "log",
    ylim  = [1, 250],
    xlim  = [1, 150],
    xlabel = "r [pc]",
    ylabel = r"B(r) [km$^{2}$/s$^{2}$]",
)

sig2
# Out:
# 44.12786785616313

# %%
model02 = lmfit.Model(bfunc02)
model02.param_names
# Out:
# ['r0', 'sig2', 'm', 's0', 'noise']

# %%
relative_uncertainty = 0.15
weights = 1.0 / (relative_uncertainty * B)
weights[-5:] /= 4.0

# %%
for p in model02.param_names:
    model02.set_param_hint(p, min=0.0)
model02.set_param_hint("sig2", value=sig2, vary=False)
#model02.set_param_hint("s0", min=1.0)
model02.print_param_hints()
# Out:
# Name      Value      Min      Max     Vary    Expr
# m           nan        0      inf     True
# noise       nan        0      inf     True
# r0          nan        0      inf     True
# s0          nan        0      inf     True
# sig2    44.1279        0      inf    False

# %%
result2 = model02.fit(
    B, 
    weights=weights,
    r=r, r0=r0, m=m, s0=s0, noise=1.0,
)

# %%
fig, _ = result2.plot()
fig.axes[0].set(
    xscale="log",
    yscale="symlog",
)
fig.axes[1].set(
    xscale="log",
    yscale="log",
);

# %%
print(result2.fit_report())
# Out:
# [[Model]]
#     Model(bfunc02)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 75
#     # data points      = 16
#     # variables        = 4
#     chi-square         = 5.92462221
#     reduced chi-square = 0.49371852
#     Akaike info crit   = -7.89554878
#     Bayesian info crit = -4.80519389
# [[Variables]]
#     r0:     8.39735035 +/- 0.52903522 (6.30%) (init = 8.818012)
#     sig2:   44.12787 (fixed)
#     m:      1.92128283 +/- 0.13164039 (6.85%) (init = 1.5)
#     s0:     0.61258284 +/- 0.22120750 (36.11%) (init = 1.73673)
#     noise:  2.03280966 +/- 0.83552872 (41.10%) (init = 1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(s0, noise) =  0.912
#     C(r0, m)     = -0.661
#     C(r0, s0)    =  0.475
#     C(r0, noise) =  0.398
#     C(m, s0)     = -0.136
#     C(m, noise)  =  0.124

# %%
#for p in result2.model.param_names:
#    result2.params[p].stderr = result2.params[p].value * 0.1

# %%
result2.conf_interval()
print(result2.ci_report())
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\lmfit\confidence.py:312: UserWarning: Bound reached with prob(s0=0.0) = 0.8217213654048254 < max(sigmas)
#   warn(errmsg)
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\lmfit\confidence.py:312: UserWarning: Bound reached with prob(noise=0.0) = 0.9035426258200413 < max(sigmas)
#   warn(errmsg)
#           99.73%    95.45%    68.27%    _BEST_    68.27%    95.45%    99.73%
#  r0   :  -1.47513  -0.93895  -0.46008   8.39735  +0.51900  +1.20817  +2.31672
#  m    :  -0.46444  -0.26694  -0.12654   1.92128  +0.13453  +0.30004  +0.53803
#  s0   :      -inf      -inf  -0.18521   0.61258  +0.14079  +0.30477  +0.53847
#  noise:      -inf      -inf  -0.98024   2.03281  +0.51777  +0.97956  +1.49463

# %%
plt.style.use([
    "seaborn-poster",
])

# %%
plot_limits = {
    "s0": [0.0, 2.0],
    "m": [0.8, 3],
    "r0": [5.0, 16.0],
    "noise": [0.0, 6.0],
}

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

plt.title('NGC 595')
levels = [0.6827, 0.9545, 0.9973]
colors = ["g", "y", "r"]

for ax, [xvar, yvar] in zip(axes.flat, [
    ["s0", "noise"],
    ["r0", "m"],
    ["m", "s0"],
    ["r0", "s0"],
]):
    cx, cy, grid = lmfit.conf_interval2d(
        result2, result2, xvar, yvar, 30, 30,
        limits=[plot_limits[xvar], plot_limits[yvar]],
    )
    ctp = ax.contour(cx, cy, grid, levels, colors=colors)
    ax.set_xlabel(xvar)
    ax.set_ylabel(yvar)

fig.tight_layout();

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 31.372751474380493 seconds ---
