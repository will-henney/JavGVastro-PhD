# %%
import time
start_time=time.time()
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from astropy.coordinates import SkyCoord, EarthLocation
from astropy import units as u
from astropy.time import Time
import pickle
import itertools
import statsmodels.api as sm
from scipy import interpolate

from sabreMod import sosf,sosfn
plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="12"

# %% [markdown]
# ISIS red arm

# %%
Red=dict()
Red[0]='Obs\ISIS.595.Red.txt'
DataR=pd.read_table(Red[0])
DataR=DataR.rename(columns={"Center":"Center.0","ErrC":"ErrC.0","Width":"Width.0","ErrW":"ErrW.0","Peak":"Peak.0","ErrP":"ErrP.0","Line":"Line.0","ErrL":"ErrL.0"})
DataR
# Out:
#       Pos        X     Y  Slit                Archivo  Center.0  ErrC.0  \
# 0     1.0  199.809  22.0   1.0  595r1_878-001004.xlsx  6562.267   0.211
# 1     2.0  198.468  22.0   1.0  595r1_878-005008.xlsx  6557.690   0.228
# 2     3.0  197.127  22.0   1.0  595r1_878-009012.xlsx  6557.705   0.108
# 3     4.0  195.786  22.0   1.0  595r1_878-013016.xlsx  6557.593   0.083
# 4     5.0  194.445  22.0   1.0  595r1_878-017020.xlsx  6557.546   0.082
# ...   ...      ...   ...   ...                    ...       ...     ...
# 1495  NaN      NaN   NaN   NaN                    NaN       NaN     NaN
# 1496  NaN      NaN   NaN   NaN                    NaN       NaN     NaN
# 1497  NaN      NaN   NaN   NaN                    NaN       NaN     NaN
# 1498  NaN      NaN   NaN   NaN                    NaN       NaN     NaN
# 1499  NaN      NaN   NaN   NaN                    NaN       NaN     NaN
#
#       Width.0  ErrW.0  Peak.0  ...  Line.3  ErrL.3  Center.4  ErrC.4  Width.4  \
# 0      -4.288   0.464  -31.70  ...   8.525   7.594  6726.756   0.296    1.419
# 1       0.882   0.404   16.36  ...  18.900   6.029  6725.364   0.150    0.913
# 2       0.970   0.262   35.66  ...   7.970   9.081  6724.843   0.551    2.664
# 3       0.916   0.202   41.62  ...  17.990   8.705  6725.727   0.605    2.698
# 4       0.813   0.195   40.74  ... -14.250  -5.156  6724.045   0.154    0.948
# ...       ...     ...     ...  ...     ...     ...       ...     ...      ...
# 1495      NaN     NaN     NaN  ...     NaN     NaN       NaN     NaN      NaN
# 1496      NaN     NaN     NaN  ...     NaN     NaN       NaN     NaN      NaN
# 1497      NaN     NaN     NaN  ...     NaN     NaN       NaN     NaN      NaN
# 1498      NaN     NaN     NaN  ...     NaN     NaN       NaN     NaN      NaN
# 1499      NaN     NaN     NaN  ...     NaN     NaN       NaN     NaN      NaN
#
#       ErrW.4  Peak.4  ErrP.4  Line.4  ErrL.4
# 0      0.544  13.700   5.127  20.690   7.479
# 1      0.297  -1.937   4.781  -1.883  -4.577
# 2      1.016   8.852   3.333  25.110   9.367
# 3      1.057   3.842   2.687  11.030   8.172
# 4      0.355  -8.792   4.558  -8.870  -5.081
# ...      ...     ...     ...     ...     ...
# 1495     NaN     NaN     NaN     NaN     NaN
# 1496     NaN     NaN     NaN     NaN     NaN
# 1497     NaN     NaN     NaN     NaN     NaN
# 1498     NaN     NaN     NaN     NaN     NaN
# 1499     NaN     NaN     NaN     NaN     NaN
#
# [1500 rows x 45 columns]

# %%
i=1#[NII]6548
Dt1=[DataR.X, DataR.Y,DataR["Center."+str(i)],DataR["ErrC."+str(i)],DataR["Width."+str(i)],DataR["ErrW."+str(i)],DataR["Peak."+str(i)],DataR["ErrP."+str(i)],DataR["Line."+str(i)],DataR["ErrL."+str(i)]]
Dt1=pd.DataFrame(Dt1).T
Dt1.describe()
# Out:
#                  X            Y     Center.1       ErrC.1      Width.1  \
# count  1350.000000  1350.000000  1350.000000  1350.000000  1350.000000
# mean     99.904500    10.568889  6538.234511     0.448991     4.075753
# std      58.087231     6.978156   178.083009     0.504593     4.673074
# min       0.000000     0.000000     0.000000     0.000000    -0.911000
# 25%      49.617000     5.000000  6542.571000     0.083000     1.033000
# 50%      99.904500    11.000000  6542.905500     0.262500     2.122000
# 75%     150.192000    15.000000  6543.224750     0.575000     3.709500
# max     199.809000    22.000000  6552.261000     2.780000    16.600000
#
#             ErrW.1       Peak.1       ErrP.1       Line.1       ErrL.1
# count  1350.000000  1350.000000  1350.000000  1350.000000  1350.000000
# mean      1.036715    26.465967     3.153491    36.979536     6.360338
# std       1.024268    77.382351    27.423809    53.370897     4.854849
# min       0.000000    -4.438000     0.000000   -15.590000    -6.101000
# 25%       0.227250     4.273250     1.241500    14.760000     3.121500
# 50%       0.700500     7.166000     1.749000    21.220000     4.548000
# 75%       1.513000    15.915000     2.649500    41.520000     7.028250
# max       6.040000  1527.000000   953.500000   621.200000    59.870000

# %%
i=2#[NII]6584
Dt2=[DataR.X, DataR.Y,DataR["Center."+str(i)],DataR["ErrC."+str(i)],DataR["Width."+str(i)],DataR["ErrW."+str(i)],DataR["Peak."+str(i)],DataR["ErrP."+str(i)],DataR["Line."+str(i)],DataR["ErrL."+str(i)]]
Dt2=pd.DataFrame(Dt2).T
Dt2.describe()
# Out:
#                  X            Y     Center.2       ErrC.2      Width.2  \
# count  1350.000000  1350.000000  1350.000000  1350.000000  1350.000000
# mean     99.904500    10.568889  6573.708215     0.448991     4.075753
# std      58.087231     6.978156   179.049181     0.504593     4.673074
# min       0.000000     0.000000     0.000000     0.000000    -0.911000
# 25%      49.617000     5.000000  6578.071000     0.083000     1.033000
# 50%      99.904500    11.000000  6578.405500     0.262500     2.122000
# 75%     150.192000    15.000000  6578.724750     0.575000     3.709500
# max     199.809000    22.000000  6587.761000     2.780000    16.600000
#
#             ErrW.2       Peak.2       ErrP.2       Line.2       ErrL.2
# count  1350.000000  1350.000000  1350.000000  1350.000000  1350.000000
# mean      1.036715    79.396675     9.460140   110.937604    19.080861
# std       1.024268   232.141392    82.258597   160.112706    14.564336
# min       0.000000   -13.310000     0.000000   -46.770000   -18.300000
# 25%       0.227250    12.820000     3.725000    44.275000     9.365000
# 50%       0.700500    21.500000     5.247000    63.665000    13.645000
# 75%       1.513000    47.737500     7.948250   124.575000    21.087500
# max       6.040000  4581.000000  2860.000000  1864.000000   179.600000

# %% [markdown]
# [NII]6548

# %% [markdown]
# Peak

# %%
#data_P=(Dt1.round(2)).pivot(index='Y', columns='X', values='Peak.1')#TableFormat

sz=2
wd=DataR.X.max()-DataR.X.min()
hd=DataR.Y.max()-DataR.Y.min()
ar=wd/hd

#fig, ax = plt.subplots(figsize=(sz*ar,sz))
#sns.heatmap(data_P, cmap="inferno")
#plt.gca().invert_yaxis()
#plt.axis('equal')

# %%
fig, ax = plt.subplots(figsize=(sz*ar,sz))

plt.scatter(Dt1.X,Dt1.Y,c=np.log10(Dt1['Peak.1']), s=8,marker='s',cmap="inferno")
cbar = plt.colorbar()
cbar.set_label('Log Flux', rotation=270, labelpad=15)  
plt.axis('equal')
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (-9.990450000000003, 209.79945000000004, -1.1, 23.1)

# %%
mP1=(Dt1.X>80)&(Dt1.X<117)&(Dt1["Peak.1"]>0)
data_P1=(Dt1[mP1].round(2)).pivot(index='Y', columns='X', values='Peak.1')#TableFormat

sz=4
wd=Dt1[mP1].X.max()-Dt1[mP1].X.min()
hd=Dt1[mP1].Y.max()-Dt1[mP1].Y.min()
ar=wd/hd

fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_P1, cmap="inferno")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 28.0, 0.0, 9.0)

# %% [markdown]
# Heliocentric Radial velocity

# %%
l=[6548.0]#AngstromsR

c=299792.459#km/s

RA=23.638292#J2000
Dec=30.784889#J200

orm = EarthLocation.of_site('Roque de los Muchachos')
sc = SkyCoord(ra=RA*u.deg, dec=Dec*u.deg)
heliocorr = sc.radial_velocity_correction('heliocentric', obstime=Time('1992-8-18'), location=orm) 
heliocorr.to(u.km/u.s) 
corrhelio=np.array(heliocorr.to(u.km/u.s))

RVo=c*(Dt1["Center.1"]-l)/l
RV=RVo+corrhelio

Dt1=Dt1.assign(RV=RV.values)

# %%
data_VR=(Dt1[mP1].round(2)).pivot(index='Y', columns='X', values='RV')#TableFormat
fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_VR, cmap="viridis")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 28.0, 0.0, 9.0)

# %%
sns.distplot(Dt1.RV[mP1],bins=25)

# %% [markdown]
# Sigma

# %%
T=8350#K Table 5

Xw=14.0067#
SI=12#km/s

#SigmaObs
a=0.6006/1.414
SigmaObs=a*(Dt1["Width.1"]/l)*c
    
#SigmaTerm
b=166.6/1.414
SigmaTerm=np.sqrt(b*(T/10000)/Xw)

SigmaDisp=np.sqrt(SigmaObs**2-SigmaTerm**2-SI**2)

Dt1=Dt1.assign(Sig=SigmaDisp.values)
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#data_SR=(Dt1.round(2)).pivot(index='Y', columns='X', values='Sig')#TableFormat
#fig, ax = plt.subplots(figsize=(sz*ar,sz))
#sns.heatmap(data_SR, cmap="mako")
#plt.gca().invert_yaxis()
#plt.axis('equal')

# %%
sns.distplot(Dt1.Sig,bins=25)

# %%
Dt1II=Dt1
mS1=Dt1II.Sig<50

# %%
#data_S1=(Dt1II[mS1].round(2)).pivot(index='Y', columns='X', values='Sig')#TableFormat
#fig, ax = plt.subplots(figsize=(sz*ar,sz))
#sns.heatmap(data_S1, cmap="mako")
#plt.gca().invert_yaxis()
#plt.axis('equal')

# %%
sns.distplot(Dt1II[mS1].Sig,bins=25)

# %% [markdown]
# [NII]6584

# %% [markdown]
# Peak

# %%
#data_P2=(Dt2.round(2)).pivot(index='Y', columns='X', values='Peak.2')#TableFormat

sz=2
wd=DataR.X.max()-DataR.X.min()
hd=DataR.Y.max()-DataR.Y.min()
ar=wd/hd

#fig, ax = plt.subplots(figsize=(sz*ar,sz))
#sns.heatmap(data_P2, cmap="inferno")
#plt.gca().invert_yaxis()
#plt.axis('equal')

# %%
fig, ax = plt.subplots(figsize=(sz*ar,sz))

plt.scatter(Dt2.X,Dt2.Y,c=np.log10(Dt2['Peak.2']), s=8,marker='s',cmap="inferno")
cbar = plt.colorbar()
cbar.set_label('Log Flux', rotation=270, labelpad=15)  
plt.axis('equal')
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (-9.990450000000003, 209.79945000000004, -1.1, 23.1)

# %%
mP2=(Dt2.X>80)&(Dt2.X<120)&(Dt2["Peak.2"]>0)
data_P2=(Dt2[mP2].round(2)).pivot(index='Y', columns='X', values='Peak.2')#TableFormat

sz=7
wd=Dt2[mP2].X.max()-Dt2[mP2].X.min()
hd=Dt2[mP2].Y.max()-Dt2[mP2].Y.min()
ar=wd/hd

fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_P2, cmap="inferno")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 30.0, 0.0, 9.0)

# %%
l=[6583.4]#AngstromsR

c=299792.459#km/s

RA=23.638292#J2000
Dec=30.784889#J200

orm = EarthLocation.of_site('Roque de los Muchachos')
sc = SkyCoord(ra=RA*u.deg, dec=Dec*u.deg)
heliocorr = sc.radial_velocity_correction('heliocentric', obstime=Time('1992-8-18'), location=orm) 
heliocorr.to(u.km/u.s) 
corrhelio=np.array(heliocorr.to(u.km/u.s))

RVo=c*(Dt2["Center.2"]-l)/l
RV=RVo+corrhelio

Dt2=Dt2.assign(RV=RV.values)

# %%
data_VB=(Dt2[mP2].round(2)).pivot(index='Y', columns='X', values='RV')#TableFormat
fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_VB, cmap="viridis")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 30.0, 0.0, 9.0)

# %%
sns.distplot(Dt2[mP2].RV,bins=25)

# %%
T=8350#K Table 5

Xw=14.0067#
SI=12#km/s

#SigmaObs
a=0.6006/1.414
SigmaObs=a*(Dt2["Width.2"]/l)*c
    
#SigmaTerm
b=166.6/1.414
SigmaTerm=np.sqrt(b*(T/10000)/Xw)

SigmaDisp=np.sqrt(SigmaObs**2-SigmaTerm**2-SI**2)

Dt2=Dt2.assign(Sig=SigmaDisp.values)
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#data_SB=(Dt2.round(2)).pivot(index='Y', columns='X', values='Sig')#TableFormat
#fig, ax = plt.subplots(figsize=(sz*ar,sz))
#sns.heatmap(data_SB, cmap="mako")
#plt.gca().invert_yaxis()
#plt.axis('equal')

# %%
sns.distplot(Dt2.Sig,bins=25)

# %%
Dt2II=Dt2
mS2=((Dt2II["Sig"]<50))

# %%
#data_SB=(Dt2II[mS2].round(2)).pivot(index='Y', columns='X', values='Sig')#TableFormat
#fig, ax = plt.subplots(figsize=(sz*ar,sz))
#sns.heatmap(data_SB, cmap="mako")
#plt.gca().invert_yaxis()
#plt.axis('equal')

# %%
sns.distplot(Dt2II[mS2].Sig,bins=25)

# %% [markdown]
# Comparison

# %%
Dt1c=Dt1[mP1]
Dt2c=Dt2[mP2]

# %% [markdown]
# Peak

# %%
sns.distplot(Dt1c["Peak.1"],bins=25)
sns.distplot(Dt2c["Peak.2"],bins=25)

# %% [markdown]
# Normalize emission

# %%
PeakN=Dt1c["Peak.1"]/Dt1c["Peak.1"].max()
Dt1c=Dt1c.assign(PeakN=PeakN.values)

# %%
PeakN=Dt2c["Peak.2"]/Dt2c["Peak.2"].max()
Dt2c=Dt2c.assign(PeakN=PeakN.values)

# %%
sns.distplot(Dt1c["PeakN"],bins=25)
sns.distplot(Dt2c["PeakN"],bins=25)

# %% [markdown]
# Radial Velocity

# %%
sns.distplot(Dt1c.RV,bins=25)
sns.distplot(Dt2c.RV,bins=25)

# %% [markdown]
# Sigma

# %%
sns.distplot(Dt1c.Sig,bins=25)
sns.distplot(Dt2c.Sig,bins=25)

# %% [markdown]
# Structure Function

# %%
pc=4.16

# %%
SF=sosf(Dt1c)
SF.Lag=SF.Lag*pc

fig,ax=plt.subplots()

ax.errorbar(SF.Lag,SF.Nmqvd, yerr=SF.ErrY, marker='.', fmt=' ',color="blue", ecolor="blue",
                     alpha=0.5, markersize=5)

ax.set(xscale='log',yscale='log')
# Out:
# 1.0
# [None, None]

# %%
x=SF['Lag']
y=SF['Nmqvd']-(Dt1c["RV"].std())**2
tck=interpolate.splrep(x,y,s=0)
grid=np.linspace(x.min(),x.max(),num=len(x))
ynew=interpolate.splev(grid,tck,der=0)
inter=pd.DataFrame([grid,ynew]).T
SFr=interpolate.sproot(tck)
SFr
# Out:
# array([29.98911832])

# %%
s=SFr[0]

# %%
ss=np.round((Dt1c["RV"].std())**2,2)

# %%
fig,ax=plt.subplots(figsize=(7,7))

ax.errorbar(SF.Lag,SF.Nmqvd, yerr=SF.ErrY, marker='.', fmt=' ',color="blue", ecolor="blue",
                     alpha=0.75, markersize=20)

ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')

plt.axhline(y=ss, color='r', linestyle='--')
ax.text(0.25, 0.8,'$σ_{POS}^{2}$ = '+str(ss)+' km/s', ha='center', va='center', transform=ax.transAxes, color='r')


plt.axvline(x=s, color='k', linestyle='--')

lo=s

n=1.5

x=np.linspace(int(SF.Lag.min()),int(SF.Lag.max()),100)
c=1/(1+(x/lo)**n)

y=2*(1-c)*ss

plt.loglog(x,y,color='k', linestyle='-')


textstr = '\n'.join(('595 I [NII] 6548' ,r'$m=%.2f$'%n, r'$r_{0}=%.2f$' % s+' [pc]',
                     r'$σ_{POS}=%.2f$' % (Dt1c["RV"].std()) + ' [km/s]' , r'$σ_{LOS}=%.2f$'%(Dt1c["Sig"].std()) + ' [km/s]' )) 

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
ax.text(0.65, .3, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="20"

#ax.set_xlim(1, 250)
#ax.set_ylim(1, 750)

#fig.savefig('Img//'+samples[0][i]+'.pdf')

# %%
SF1=SF

# %%
SF=sosf(Dt2c)
SF.Lag=SF.Lag*pc

fig,ax=plt.subplots()

ax.errorbar(SF.Lag,SF.Nmqvd, yerr=SF.ErrY, marker='.', fmt=' ',color="blue", ecolor="blue",
                     alpha=0.5, markersize=5)

ax.set(xscale='log',yscale='log')
# Out:
# 1.0
# [None, None]

# %%
x=SF['Lag']
y=SF['Nmqvd']-(Dt2c["RV"].std())**2
tck=interpolate.splrep(x,y,s=0)
grid=np.linspace(x.min(),x.max(),num=len(x))
ynew=interpolate.splev(grid,tck,der=0)
inter=pd.DataFrame([grid,ynew]).T
SFr=interpolate.sproot(tck)
SFr
# Out:
# array([29.73793218])

# %%
s=SFr[0]

# %%
ss=np.round((Dt2c["RV"].std())**2,2)

# %%
fig,ax=plt.subplots(figsize=(7,7))

ax.errorbar(SF.Lag,SF.Nmqvd, yerr=SF.ErrY, marker='.', fmt=' ',color="blue", ecolor="blue",
                     alpha=0.75, markersize=20)

ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')

plt.axhline(y=ss, color='r', linestyle='--')
ax.text(0.25, 0.8,'$σ_{POS}^{2}$ = '+str(ss)+' km/s', ha='center', va='center', transform=ax.transAxes, color='r')


plt.axvline(x=s, color='k', linestyle='--')

lo=s

n=1.5

x=np.linspace(int(SF.Lag.min()),int(SF.Lag.max()),100)
c=1/(1+(x/lo)**n)

y=2*(1-c)*ss

plt.loglog(x,y,color='k', linestyle='-')


textstr = '\n'.join(('595 I [NII] 6584' ,r'$m=%.2f$'%n, r'$r_{0}=%.2f$' % s+' [pc]',
                     r'$σ_{POS}=%.2f$' % (Dt2c["RV"].std()) + ' [km/s]' , r'$σ_{LOS}=%.2f$'%(Dt2c["Sig"].std()) + ' [km/s]' )) 

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
ax.text(0.65, .3, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="20"

#ax.set_xlim(1, 250)
#ax.set_ylim(1, 750)

#fig.savefig('Img//'+samples[0][i]+'.pdf')

# %%
SF2=SF

# %%
fig,ax=plt.subplots(figsize=(7,7))

ax.errorbar(SF1.Lag,SF1.Nmqvd, yerr=SF1.ErrY, marker='.', fmt=' ',color="red", ecolor="red",
                     alpha=0.45, markersize=8,label='6548')

ax.errorbar(SF2.Lag,SF2.Nmqvd, yerr=SF2.ErrY, marker='+', fmt=' ',color="navy", ecolor="navy",
                     alpha=0.45, markersize=8,label='6584')

plt.yscale('log')
plt.xscale('log')
ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.legend()

# %%
plt.scatter(Dt1c["Peak.1"]/Dt1c["Peak.1"].max(),Dt1c["Sig"],alpha=0.35,marker='d',color="red",label='6548')
plt.scatter(Dt2c["Peak.2"]/Dt2c["Peak.2"].max(),Dt2c["Sig"],alpha=0.35,marker='+',color="navy",label='6584')

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 14.499227285385132 seconds ---
