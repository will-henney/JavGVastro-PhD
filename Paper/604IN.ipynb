# %%
import time
start_time=time.time()
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from astropy.coordinates import SkyCoord, EarthLocation
from astropy import units as u
from astropy.time import Time
import pickle
import itertools
import statsmodels.api as sm
from scipy import interpolate

from sabreMod import sosf,sosfn
plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="12"

# %% [markdown]
# ISIS red arm

# %%
Red=dict()
Red[0]='Obs\ISIS.604.Red.txt'
DataR=pd.read_table(Red[0])
DataR=DataR.rename(columns={"Center":"Center.0","ErrC":"ErrC.0","Width":"Width.0","ErrW":"ErrW.0","Peak":"Peak.0","ErrP":"ErrP.0","Line":"Line.0","ErrL":"ErrL.0"})
DataR
# Out:
#       Pos  Slit       X     Y                 Archivo  Center.0  ErrC.0  \
# 0       1     1  199.81  19.6   604R1_778-001004.xlsx  6560.006   0.419
# 1       2     1  198.47  19.6   604R1_778-005008.xlsx  6559.806   0.427
# 2       3     1  197.13  19.6   604R1_778-009012.xlsx  6565.844   6.249
# 3       4     1  195.79  19.6   604R1_778-013016.xlsx  6563.614   1.206
# 4       5     1  194.45  19.6   604R1_778-017020.xlsx  6560.380   0.479
# ...   ...   ...     ...   ...                     ...       ...     ...
# 1495  146    10    5.36   0.0  604R10_796-581584.xlsx  6562.497   1.075
# 1496  147    10    4.02   0.0  604R10_796-585588.xlsx  6559.596   0.502
# 1497  148    10    2.68   0.0  604R10_796-589592.xlsx  6555.097   0.403
# 1498  149    10    1.34   0.0  604R10_796-593596.xlsx  6559.274   0.471
# 1499  150    10    0.00   0.0  604R10_796-597600.xlsx  6560.193   1.002
#
#       Width.0  ErrW.0  Peak.0  ...   Line.3    ErrL.3  Center.4  ErrC.4  \
# 0       3.152   0.760  -19.79  ...   6.9110    9.8280  6724.307   1.618
# 1       3.849   1.260  -18.81  ...   1.5190    0.0000  6726.936   0.812
# 2      28.117  18.167  -16.44  ...  -7.2300   -6.1340  6723.383   0.606
# 3      22.266   4.208  -14.54  ...  -0.1011   -0.5723  6725.799   0.636
# 4       3.310   0.990  -16.68  ... -20.7700  -12.5400  6728.612   0.685
# ...       ...     ...     ...  ...      ...       ...       ...     ...
# 1495   25.496   4.464  -16.81  ...  12.7500    4.8210  6726.949   0.155
# 1496    2.088   1.022  -14.64  ... -32.3900 -237.2000  6732.367   0.000
# 1497    1.710   0.586  -13.80  ... -34.2900  -13.9000  6730.058   1.412
# 1498    2.991   0.726  -17.67  ...   8.3980   12.5800  6728.062   1.317
# 1499    2.166   1.288  -14.71  ...  26.8400   73.0300  6728.064  20.283
#
#       Width.4  ErrW.4  Peak.4  ErrP.4  Line.4  ErrL.4
# 0       2.765   2.312  -3.363   3.125  -9.896 -12.140
# 1       2.295   1.196   4.827   3.316  11.790   8.589
# 2       1.294   0.730   2.938   4.510   4.045   7.195
# 3       1.021   0.724  -8.003   6.818  -8.701  -7.102
# 4       3.266   1.290  -4.778   3.152 -16.610  -9.432
# ...       ...     ...     ...     ...     ...     ...
# 1495    0.835   0.259  -6.647   4.902  -5.906  -4.347
# 1496    0.196   0.000   8.149   0.000   1.704   4.226
# 1497    7.141   3.258   3.012   1.870  22.900  19.520
# 1498    3.541   2.472   3.947   3.851  14.880  11.680
# 1499  -10.946  23.835  -2.521  11.400  29.380  74.200
#
# [1500 rows x 45 columns]

# %%
i=1#[NII]6548
Dt1=[DataR.X, DataR.Y,DataR["Center."+str(i)],DataR["ErrC."+str(i)],DataR["Width."+str(i)],DataR["ErrW."+str(i)],DataR["Peak."+str(i)],DataR["ErrP."+str(i)],DataR["Line."+str(i)],DataR["ErrL."+str(i)]]
Dt1=pd.DataFrame(Dt1).T
Dt1.describe()
# Out:
#                  X            Y     Center.1       ErrC.1      Width.1  \
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean     99.905000     9.390000  6529.778602     0.621307     3.510133
# std      58.085176     6.252917   292.423742     1.025068    13.097647
# min       0.000000     0.000000     0.000000     0.000000  -333.233000
# 25%      49.620000     4.000000  6541.722500     0.044000     0.815000
# 50%      99.905000     9.000000  6541.965500     0.182000     1.092000
# 75%     150.190000    15.000000  6543.201500     1.061250     3.808500
# max     199.810000    19.600000  6567.098000    19.952000   235.071000
#
#             ErrW.1        Peak.1         ErrP.1         Line.1        ErrL.1
# count  1500.000000  1.500000e+03    1500.000000    1500.000000   1500.000000
# mean      1.249295  2.669074e+03     117.219037     162.039307     26.483578
# std       1.844833  9.762238e+04    4257.761300    5076.097790   1163.431487
# min       0.000000 -6.668000e+01       0.000000  -16690.000000 -11310.000000
# 25%       0.108000  3.058500e+00       1.303500       6.502500      2.834500
# 50%       0.391500  6.879500e+00       2.649500      18.965000      4.298000
# 75%       2.051750  4.451250e+01       3.989500      52.000000     11.060000
# max      19.613000  3.778000e+06  164900.000000  195200.000000  43110.000000

# %%
i=2#[NII]6584
Dt2=[DataR.X, DataR.Y,DataR["Center."+str(i)],DataR["ErrC."+str(i)],DataR["Width."+str(i)],DataR["ErrW."+str(i)],DataR["Peak."+str(i)],DataR["ErrP."+str(i)],DataR["Line."+str(i)],DataR["ErrL."+str(i)]]
Dt2=pd.DataFrame(Dt2).T
Dt2.describe()
# Out:
#                  X            Y     Center.2       ErrC.2      Width.2  \
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean     99.905000     9.390000  6565.207602     0.621307     3.510133
# std      58.085176     6.252917   294.010220     1.025068    13.097647
# min       0.000000     0.000000     0.000000     0.000000  -333.233000
# 25%      49.620000     4.000000  6577.222500     0.044000     0.815000
# 50%      99.905000     9.000000  6577.465500     0.182000     1.092000
# 75%     150.190000    15.000000  6578.701500     1.061250     3.808500
# max     199.810000    19.600000  6602.598000    19.952000   235.071000
#
#             ErrW.2        Peak.2         ErrP.2         Line.2         ErrL.2
# count  1500.000000  1.500000e+03    1500.000000    1500.000000    1500.000000
# mean      1.249295  8.004554e+03     351.589532     486.186406      79.421014
# std       1.844833  2.927640e+05   12770.701858   15230.843743    3489.631692
# min       0.000000 -2.000000e+02       0.000000  -50060.000000  -33940.000000
# 25%       0.108000  9.176250e+00       3.909750      19.510000       8.504500
# 50%       0.391500  2.063500e+01       7.947500      56.900000      12.890000
# 75%       2.051750  1.335500e+02      11.970000     156.000000      33.180000
# max      19.613000  1.133000e+07  494600.000000  585700.000000  129300.000000

# %% [markdown]
# [NII]6548

# %% [markdown]
# Peak

# %%
data_P=(Dt1.round(2)).pivot(index='Y', columns='X', values='Peak.1')#TableFormat

sz=2
wd=DataR.X.max()-DataR.X.min()
hd=DataR.Y.max()-DataR.Y.min()
ar=wd/hd

fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_P, cmap="inferno")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 150.0, 0.0, 10.0)

# %%
mP1=(Dt1.X>65)&(Dt1.X<145)&(Dt1["Peak.1"]>0)
data_P1=(Dt1[mP1].round(2)).pivot(index='Y', columns='X', values='Peak.1')#TableFormat

sz=4
wd=Dt1[mP1].X.max()-Dt1[mP1].X.min()
hd=Dt1[mP1].Y.max()-Dt1[mP1].Y.min()
ar=wd/hd

fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_P1, cmap="inferno")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 60.0, 0.0, 10.0)

# %% [markdown]
# Heliocentric Radial velocity

# %%
l=[6548.0]#AngstromsR

c=299792.459#km/s

RA=23.638292#J2000
Dec=30.784889#J200

orm = EarthLocation.of_site('Roque de los Muchachos')
sc = SkyCoord(ra=RA*u.deg, dec=Dec*u.deg)
heliocorr = sc.radial_velocity_correction('heliocentric', obstime=Time('1992-8-18'), location=orm) 
heliocorr.to(u.km/u.s) 
corrhelio=np.array(heliocorr.to(u.km/u.s))

RVo=c*(Dt1["Center.1"]-l)/l
RV=RVo+corrhelio

Dt1=Dt1.assign(RV=RV.values)

# %%
data_VR=(Dt1[mP1].round(2)).pivot(index='Y', columns='X', values='RV')#TableFormat
fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_VR, cmap="viridis")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 60.0, 0.0, 10.0)

# %%
sns.distplot(Dt1.RV[mP1],bins=25)

# %%
Dt1I=Dt1[mP1]
mR1=(Dt1I.RV>-270)&(Dt1I.RV<-220)

# %%
data_VR=(Dt1I[mR1].round(2)).pivot(index='Y', columns='X', values='RV')#TableFormat
fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_VR, cmap="viridis")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 60.0, 0.0, 10.0)

# %% [markdown]
# Sigma

# %%
T=8350#K Table 5

Xw=14.0067#
SI=12#km/s

#SigmaObs
a=0.6006/1.414
SigmaObs=a*(Dt1I["Width.1"]/l)*c
    
#SigmaTerm
b=166.6/1.414
SigmaTerm=np.sqrt(b*(T/10000)/Xw)

SigmaDisp=np.sqrt(SigmaObs**2-SigmaTerm**2-SI**2)

Dt1I=Dt1I.assign(Sig=SigmaDisp.values)
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data_SR=(Dt1I.round(2)).pivot(index='Y', columns='X', values='Sig')#TableFormat
fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_SR, cmap="mako")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 60.0, 0.0, 10.0)

# %%
sns.distplot(Dt1I.Sig,bins=25)

# %%
Dt1II=Dt1I[mR1]
mS1=Dt1II.Sig<40

# %%
data_S1=(Dt1II[mS1].round(2)).pivot(index='Y', columns='X', values='Sig')#TableFormat
fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_S1, cmap="mako")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 60.0, 0.0, 10.0)

# %%
sns.distplot(Dt1II[mS1].Sig,bins=25)

# %% [markdown]
# [NII]6584

# %% [markdown]
# Peak

# %%
data_P2=(Dt2.round(2)).pivot(index='Y', columns='X', values='Peak.2')#TableFormat

sz=2
wd=DataR.X.max()-DataR.X.min()
hd=DataR.Y.max()-DataR.Y.min()
ar=wd/hd

fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_P2, cmap="inferno")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 150.0, 0.0, 10.0)

# %%
mP2=(Dt2.X>65)&(Dt2.X<145)&(Dt2["Peak.2"]>0)
data_P2=(Dt2[mP2].round(2)).pivot(index='Y', columns='X', values='Peak.2')#TableFormat

sz=7
wd=Dt2[mP2].X.max()-Dt2[mP2].X.min()
hd=Dt2[mP2].Y.max()-Dt2[mP2].Y.min()
ar=wd/hd

fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_P2, cmap="inferno")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 60.0, 0.0, 10.0)

# %%
l=[6583.4]#AngstromsR

c=299792.459#km/s

RA=23.638292#J2000
Dec=30.784889#J200

orm = EarthLocation.of_site('Roque de los Muchachos')
sc = SkyCoord(ra=RA*u.deg, dec=Dec*u.deg)
heliocorr = sc.radial_velocity_correction('heliocentric', obstime=Time('1992-8-18'), location=orm) 
heliocorr.to(u.km/u.s) 
corrhelio=np.array(heliocorr.to(u.km/u.s))

RVo=c*(Dt2["Center.2"]-l)/l
RV=RVo+corrhelio

Dt2=Dt2.assign(RV=RV.values)

# %%
data_VB=(Dt2[mP2].round(2)).pivot(index='Y', columns='X', values='RV')#TableFormat
fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_VB, cmap="viridis")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 60.0, 0.0, 10.0)

# %%
sns.distplot(Dt2[mP2].RV,bins=25)

# %%
Dt2I=Dt2[mP2]
mR2=(Dt2I.RV>-270)&(Dt2I.RV<-220)

# %%
data_VB=(Dt2I[mR2].round(2)).pivot(index='Y', columns='X', values='RV')#TableFormat
fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_VB, cmap="viridis")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 60.0, 0.0, 10.0)

# %%
sns.distplot(Dt2I[mR2].RV,bins=25)

# %%
T=8350#K Table 5

Xw=14.0067#
SI=12#km/s

#SigmaObs
a=0.6006/1.414
SigmaObs=a*(Dt2I["Width.2"]/l)*c
    
#SigmaTerm
b=166.6/1.414
SigmaTerm=np.sqrt(b*(T/10000)/Xw)

SigmaDisp=np.sqrt(SigmaObs**2-SigmaTerm**2-SI**2)

Dt2I=Dt2I.assign(Sig=SigmaDisp.values)
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data_SB=(Dt2I.round(2)).pivot(index='Y', columns='X', values='Sig')#TableFormat
fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_SB, cmap="mako")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 60.0, 0.0, 10.0)

# %%
sns.distplot(Dt2I.Sig,bins=25)

# %%
Dt2II=Dt2I[mR2]
mS2=((Dt2II["Sig"]<40))

# %%
data_SB=(Dt2II[mS2].round(2)).pivot(index='Y', columns='X', values='Sig')#TableFormat
fig, ax = plt.subplots(figsize=(sz*ar,sz))
sns.heatmap(data_SB, cmap="mako")
plt.gca().invert_yaxis()
plt.axis('equal')
# Out:
# (0.0, 60.0, 0.0, 10.0)

# %%
sns.distplot(Dt2II[mS2].Sig,bins=25)

# %% [markdown]
# Comparison

# %%
Dt1c=Dt1II[mS1]
Dt2c=Dt2II[mS2]

# %% [markdown]
# Peak

# %%
sns.distplot(Dt1c["Peak.1"],bins=25)
sns.distplot(Dt2c["Peak.2"],bins=25)

# %% [markdown]
# Normalize emission

# %%
PeakN=Dt1c["Peak.1"]/Dt1c["Peak.1"].max()
Dt1c=Dt1c.assign(PeakN=PeakN.values)

# %%
PeakN=Dt2c["Peak.2"]/Dt2c["Peak.2"].max()
Dt2c=Dt2c.assign(PeakN=PeakN.values)

# %%
sns.distplot(Dt1c["PeakN"],bins=25)
sns.distplot(Dt2c["PeakN"],bins=25)

# %% [markdown]
# Radial Velocity

# %%
sns.distplot(Dt1c.RV,bins=25)
sns.distplot(Dt2c.RV,bins=25)

# %% [markdown]
# Sigma

# %%
sns.distplot(Dt1c.Sig,bins=25)
sns.distplot(Dt2c.Sig,bins=25)

# %% [markdown]
# Structure Function

# %%
pc=4.16

# %%
SF=sosf(Dt1c)
SF.Lag=SF.Lag*pc

fig,ax=plt.subplots()

ax.errorbar(SF.Lag,SF.Nmqvd, yerr=SF.ErrY, marker='.', fmt=' ',color="blue", ecolor="blue",
                     alpha=0.5, markersize=5)

ax.set(xscale='log',yscale='log')
# Out:
# 1.339999999999975
# [None, None]

# %%
x=SF['Lag']
y=SF['Nmqvd']-(Dt1c["RV"].std())**2
tck=interpolate.splrep(x,y,s=0)
grid=np.linspace(x.min(),x.max(),num=len(x))
ynew=interpolate.splev(grid,tck,der=0)
inter=pd.DataFrame([grid,ynew]).T
SFr=interpolate.sproot(tck)
SFr
# Out:
# array([24.59112676])

# %%
s=SFr[0]

# %%
ss=np.round((Dt1c["RV"].std())**2,2)

# %%
fig,ax=plt.subplots(figsize=(7,7))

ax.errorbar(SF.Lag,SF.Nmqvd, yerr=SF.ErrY, marker='.', fmt=' ',color="blue", ecolor="blue",
                     alpha=0.75, markersize=20)

ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')

plt.axhline(y=ss, color='r', linestyle='--')
ax.text(0.25, 0.8,'$σ_{POS}^{2}$ = '+str(ss)+' km/s', ha='center', va='center', transform=ax.transAxes, color='r')


plt.axvline(x=s, color='k', linestyle='--')

lo=s

n=1.3

x=np.linspace(int(SF.Lag.min()),int(SF.Lag.max()),100)
c=1/(1+(x/lo)**n)

y=2*(1-c)*ss

plt.loglog(x,y,color='k', linestyle='-')


textstr = '\n'.join(('604 I [NII] 6548' ,r'$m=%.2f$'%n, r'$r_{0}=%.2f$' % s+' [pc]',
                     r'$σ_{POS}=%.2f$' % (Dt1c["RV"].std()) + ' [km/s]' , r'$σ_{LOS}=%.2f$'%(Dt1c["Sig"].std()) + ' [km/s]' )) 

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
ax.text(0.65, .3, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="20"

#ax.set_xlim(1, 250)
#ax.set_ylim(1, 750)

#fig.savefig('Img//'+samples[0][i]+'.pdf')

# %%
SF1=SF

# %%
SF=sosf(Dt2c)
SF.Lag=SF.Lag*pc

fig,ax=plt.subplots()

ax.errorbar(SF.Lag,SF.Nmqvd, yerr=SF.ErrY, marker='.', fmt=' ',color="blue", ecolor="blue",
                     alpha=0.5, markersize=5)

ax.set(xscale='log',yscale='log')
# Out:
# 1.339999999999975
# [None, None]

# %%
x=SF['Lag']
y=SF['Nmqvd']-(Dt2c["RV"].std())**2
tck=interpolate.splrep(x,y,s=0)
grid=np.linspace(x.min(),x.max(),num=len(x))
ynew=interpolate.splev(grid,tck,der=0)
inter=pd.DataFrame([grid,ynew]).T
SFr=interpolate.sproot(tck)
SFr
# Out:
# array([24.00349138])

# %%
s=SFr[0]

# %%
ss=np.round((Dt2c["RV"].std())**2,2)

# %%
fig,ax=plt.subplots(figsize=(7,7))

ax.errorbar(SF.Lag,SF.Nmqvd, yerr=SF.ErrY, marker='.', fmt=' ',color="blue", ecolor="blue",
                     alpha=0.75, markersize=20)

ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')

plt.axhline(y=ss, color='r', linestyle='--')
ax.text(0.25, 0.8,'$σ_{POS}^{2}$ = '+str(ss)+' km/s', ha='center', va='center', transform=ax.transAxes, color='r')


plt.axvline(x=s, color='k', linestyle='--')

lo=s

n=1.3

x=np.linspace(int(SF.Lag.min()),int(SF.Lag.max()),100)
c=1/(1+(x/lo)**n)

y=2*(1-c)*ss

plt.loglog(x,y,color='k', linestyle='-')


textstr = '\n'.join(('604 I [NII] 6584' ,r'$m=%.2f$'%n, r'$r_{0}=%.2f$' % s+' [pc]',
                     r'$σ_{POS}=%.2f$' % (Dt2c["RV"].std()) + ' [km/s]' , r'$σ_{LOS}=%.2f$'%(Dt2c["Sig"].std()) + ' [km/s]' )) 

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
ax.text(0.65, .3, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

plt.rcParams["font.family"]="Times New Roman"
plt.rcParams["font.size"]="20"

#ax.set_xlim(1, 250)
#ax.set_ylim(1, 750)

#fig.savefig('Img//'+samples[0][i]+'.pdf')

# %%
SF2=SF

# %%
fig,ax=plt.subplots(figsize=(7,7))

ax.errorbar(SF1.Lag,SF1.Nmqvd, yerr=SF1.ErrY, marker='.', fmt=' ',color="red", ecolor="red",
                     alpha=0.45, markersize=8,label='6548')

ax.errorbar(SF2.Lag,SF2.Nmqvd, yerr=SF2.ErrY, marker='+', fmt=' ',color="navy", ecolor="navy",
                     alpha=0.45, markersize=8,label='6584')

plt.yscale('log')
plt.xscale('log')
ax.set(xlabel='lag [pc]', ylabel='S$_{2}$(l) [km$^{2}$/s$^{2}$]')
plt.legend()

# %%
fig,ax=plt.subplots(figsize=(7,7))


plt.scatter(Dt1c["Peak.1"]/Dt1c["Peak.1"].max(),Dt1c["Sig"],alpha=0.5,marker='d',color="red",label='6548')
plt.scatter(Dt2c["Peak.2"]/Dt2c["Peak.2"].max(),Dt2c["Sig"],alpha=0.5,marker='+',color="navy",label='6584')
plt.legend()
ax.set(xlabel='I', ylabel='$σ$ [km/s]')
# Out:
# [Text(0, 0.5, '$σ$ [km/s]'), Text(0.5, 0, 'I')]

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 43.30131936073303 seconds ---
