# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #Data Load

# %%
input_file_0='604.Isis.WHT.Red.txt'#astronomicalobsevations 
input_file_1='604.Isis.WHT.Blue.txt'#astronomicalobsevations

# %%
data_0R=pd.read_table(input_file_0)#PandasDataFrameOriginalData
data_1R=data_0R.copy()#DataFrameForCalculations
data_1R.head()
#data_1.describe()
# Out:
#    Pos  Slit       X     Y                Archivo    Center   ErrC   Width  \
# 0    1     1  199.81  19.6  604R1_778-001004.xlsx  6560.006  0.419   3.152
# 1    2     1  198.47  19.6  604R1_778-005008.xlsx  6559.806  0.427   3.849
# 2    3     1  197.13  19.6  604R1_778-009012.xlsx  6565.844  6.249  28.117
# 3    4     1  195.79  19.6  604R1_778-013016.xlsx  6563.614  1.206  22.266
# 4    5     1  194.45  19.6  604R1_778-017020.xlsx  6560.380  0.479   3.310
#
#      ErrW   Peak  ...   Line.3   ErrL.3  Center.4  ErrC.4  Width.4  ErrW.4  \
# 0   0.760 -19.79  ...   6.9110   9.8280  6724.307   1.618    2.765   2.312
# 1   1.260 -18.81  ...   1.5190   0.0000  6726.936   0.812    2.295   1.196
# 2  18.167 -16.44  ...  -7.2300  -6.1340  6723.383   0.606    1.294   0.730
# 3   4.208 -14.54  ...  -0.1011  -0.5723  6725.799   0.636    1.021   0.724
# 4   0.990 -16.68  ... -20.7700 -12.5400  6728.612   0.685    3.266   1.290
#
#    Peak.4  ErrP.4  Line.4  ErrL.4
# 0  -3.363   3.125  -9.896 -12.140
# 1   4.827   3.316  11.790   8.589
# 2   2.938   4.510   4.045   7.195
# 3  -8.003   6.818  -8.701  -7.102
# 4  -4.778   3.152 -16.610  -9.432
#
# [5 rows x 45 columns]

# %%
data_0B=pd.read_table(input_file_1)#PandasDataFrameOriginalData
data_1B=data_0B.copy()#DataFrameForCalculations
data_1B.head()
# Out:
#    Pos      Slit     X  Y                Archivo    Center    ErrC   Width  \
# 0    1  214.5600  19.6  1  604a1_779-001004.xlsx  4809.715  10.003 -14.310
# 1    2  213.1296  19.6  1  604a1_779-005008.xlsx  4861.424  10.792  -4.098
# 2    3  211.6992  19.6  1  604a1_779-009012.xlsx   4855.14   0.822   2.562
# 3    4  210.2688  19.6  1  604a1_779-013016.xlsx  4852.843   0.305  -1.164
# 4    5  208.8384  19.6  1  604a1_779-017020.xlsx  4875.295   0.294   0.489
#
#      ErrW   Peak  ...  Line.1  ErrL.1  Center.2  ErrC.2  Width.2  ErrW.2  \
# 0   0.000  2.583  ...  10.250  17.820  4961.214  27.812   41.454  52.778
# 1  51.891 -4.734  ...  -8.312  -8.531  4998.893   0.692    4.125   0.000
# 2   1.256 -5.215  ... -64.520 -22.320  5022.750  12.843   69.658  32.632
# 3   0.923 -9.482  ...  -3.841  -1.507  5004.753   0.192    0.961   0.346
# 4   0.375  8.143  ...  -1.367  -4.403  5004.175   0.000    0.787   0.000
#
#     Peak.2  ErrP.2  Line.2  ErrL.2
# 0   0.6969  0.4512   30.75  53.460
# 1  -5.6790  0.0000  -24.94 -25.590
# 2  -2.6100  0.7990 -193.60 -66.960
# 3 -11.2600  4.0020  -11.52  -4.521
# 4  -4.8920  0.0000   -4.10 -13.210
#
# [5 rows x 29 columns]

# %%
#Input
#Constant
c=299792.459#km/s
Dist=847000#pc
#Iraf
corrhelio=25.68#km/s
#Literature
T=8350#K
#Theory Lambda
lha=6562.8#Angstroms
lhb=4861#Angstroms
loiii=5008#Angstroms
ls=6731#Angstroms
ln=6583#Angstroms
#Atomic Weights
Hw=1.00794#
Nw=14.0067#
Sw=32.065#
Ow=15.9994#
#Observations
SigmaInstH=18#km/s
SigmaInstN=12#km/s
SigmaInstS=15#km/s
SigmaInstS=19#km/s


asctopc=(2*np.pi*Dist)/(360*3600)
asctopc
# Out:
# 4.10637187899777

# %% [markdown]
# Filter on Data

# %%
m=(data_1R.X<145)&(data_1R.X>65)
dataR=data_1R[m]

# %% [markdown]
# Emission Lines

# %%
dataHa=dataR[['X','Y','Center','Peak','Width']]
dataHa.describe()
# Out:
#                 X           Y       Center          Peak       Width
# count  600.000000  600.000000   600.000000    600.000000  600.000000
# mean   105.269000    9.390000  6556.764095   2277.239467    1.040497
# std     23.243169    6.256047     0.228108   3750.107456    0.481844
# min     65.710000    0.000000  6556.161000     27.150000   -0.966000
# 25%     85.485000    4.000000  6556.593500    281.925000    0.933750
# 50%    105.270000    9.000000  6556.767500   1017.500000    1.034500
# 75%    125.045000   15.000000  6556.896000   2403.500000    1.183250
# max    144.830000   19.600000  6557.740000  30960.000000    3.215000

# %%
dataN=dataR[['X','Y','Center.2','Peak.2','Width.2']]
dataN.describe()
# Out:
#                 X           Y     Center.2       Peak.2     Width.2
# count  600.000000  600.000000   600.000000   600.000000  600.000000
# mean   105.269000    9.390000  6577.496515   333.340168    1.307032
# std     23.243169    6.256047     0.679362   440.691257    1.698212
# min     65.710000    0.000000  6576.473000     7.410000   -0.907000
# 25%     85.485000    4.000000  6577.239750    65.727500    0.822750
# 50%    105.270000    9.000000  6577.393500   192.300000    0.939500
# 75%    125.045000   15.000000  6577.562750   413.950000    1.147000
# max    144.830000   19.600000  6583.311000  3893.000000   13.099000

# %%
dataS=dataR[['X','Y','Center.4','Peak.4','Width.4']]
dataS.describe()
# Out:
#                 X           Y     Center.4       Peak.4     Width.4
# count  600.000000  600.000000   600.000000   600.000000  600.000000
# mean   105.269000    9.390000  6725.251657   168.994135    0.545097
# std     23.243169    6.256047     0.601068   201.362479   11.093384
# min     65.710000    0.000000  6722.844000 -1343.000000 -265.259000
# 25%     85.485000    4.000000  6725.016750    40.177500    0.835500
# 50%    105.270000    9.000000  6725.171500   113.600000    0.957000
# 75%    125.045000   15.000000  6725.326000   231.750000    1.174250
# max    144.830000   19.600000  6731.423000  1568.000000    7.499000

# %% [markdown]
# Halpha Emission Line

# %%
fig, ax = plt.subplots(figsize=(14,5))
plt.scatter(dataHa.X,dataHa.Y,c=np.log10(dataHa.Peak), s=300)
plt.axis('equal')
# Out:
# (61.74180558187195,
#  148.79819441812805,
#  -1.0150488574011365,
#  20.615048857401142)

# %%
dataHf=(dataHa.round(2)).pivot(index='Y', columns='X', values='Peak')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataHf, cmap="viridis")
plt.gca().invert_yaxis()

# %%
sns.distplot(dataHa.Peak,bins=30)

# %% [markdown]
# #Radial velocity

# %% [markdown]
# $$\dfrac{\lambda_{obs}-\lambda}{\lambda}*c$$

# %%
RVHao=c*(dataHa.Center-lha)/lha

# %%
RVHa=RVHao+corrhelio
RVHa.describe()
# Out:
# count    600.000000
# mean    -250.043594
# std       10.420092
# min     -277.593319
# 25%     -257.836471
# 50%     -249.888052
# 75%     -244.018098
# max     -205.463695
# Name: Center, dtype: float64

# %%
dataHa=dataHa.assign(RV=RVHa.values)
dataHa
# Out:
#            X     Y    Center    Peak  Width          RV
# 41    144.83  19.6  6556.792   73.97  0.780 -248.768878
# 42    143.49  19.6  6556.771   94.17  0.926 -249.728170
# 43    142.15  19.6  6556.704  101.40  0.970 -252.788768
# 44    140.81  19.6  6556.538  118.20  1.154 -260.371743
# 45    139.46  19.6  6556.321  180.00  1.250 -270.284427
# ...      ...   ...       ...     ...    ...         ...
# 1446   71.07   0.0  6557.342  471.50  0.889 -223.644563
# 1447   69.73   0.0  6557.338  631.80  0.871 -223.827285
# 1448   68.39   0.0  6557.338  729.80  0.857 -223.827285
# 1449   67.05   0.0  6557.318  339.00  0.910 -224.740897
# 1450   65.71   0.0  6557.281  146.10  0.892 -226.431078
#
# [600 rows x 6 columns]

# %%
sns.distplot(dataHa.RV,bins=30)

# %%
fig, ax = plt.subplots(figsize=(14,5))
plt.scatter(dataHa.X,dataHa.Y,c=dataHa.RV, s=300)
plt.axis('equal')
# Out:
# (61.74180558187195,
#  148.79819441812805,
#  -1.0150488574011365,
#  20.615048857401142)

# %%
dataHrv=(dataHa.round(2)).pivot(index='Y', columns='X', values='RV')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataHrv, cmap="viridis")
plt.gca().invert_yaxis()

# %% [markdown]
# #Width

# %%
sns.distplot(dataHa.Width,bins=30)

# %%
m2=(dataHa.Width<3)&(dataHa.Width>0)
sns.distplot(dataHa[m2].Width,bins=30)

# %%
fig, ax = plt.subplots(figsize=(14,5))
plt.scatter(dataHa[m2].X,dataHa[m2].Y,c=dataHa[m2].Width, s=300)
plt.axis('equal')
# Out:
# (61.74180558187195,
#  148.79819441812805,
#  -1.0150488574011365,
#  20.615048857401142)

# %%
dataHw=(dataHa[m2].round(2)).pivot(index='Y', columns='X', values='Width')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataHw, cmap="viridis")
plt.gca().invert_yaxis()

# %% [markdown]
# #Sigma Disp

# %% [markdown]
# $$\sigma_{disp}^{2}=\sigma_{obs}^{2}-\sigma_{inst}^{2}-\sigma_{therm}^{2}$$

# %% [markdown]
# Sigma obs

# %%
a=0.6006/1.414
SigmaObs=a*(dataHa[m2].Width/lha)*c
SigmaObs
# Out:
# 41      15.134290
# 42      17.967119
# 43      18.820848
# 44      22.390988
# 45      24.253670
#           ...
# 1446    17.249210
# 1447    16.899957
# 1448    16.628316
# 1449    17.656672
# 1450    17.307419
# Name: Width, Length: 573, dtype: float64

# %% [markdown]
# Sigma therm

# %%
SigmaTerm=np.sqrt(166.3*(T/10000)/(Hw*1.414))
SigmaTerm
# Out:
# 9.870685562593978

# %%
SigmaDisp=np.sqrt(SigmaObs**2-SigmaTerm**2-SigmaInstH**2)
SigmaDisp.describe()
# Out:
# /home/zalenovo/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:853: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# count    265.000000
# mean      13.223510
# std        8.910126
# min        0.882001
# 25%        6.827252
# 50%       11.067999
# 75%       16.887080
# max       46.272917
# Name: Width, dtype: float64

# %%
dataHs=dataHa[m2]
dataHs=dataHs.assign(SigmaD=SigmaDisp.values)
dataHs.describe()
# Out:
#                 X           Y       Center          Peak       Width  \
# count  573.000000  573.000000   573.000000    573.000000  573.000000
# mean   105.520611    9.246248  6556.763175   2333.966597    1.113440
# std     22.820719    6.242389     0.227165   3816.888874    0.273027
# min     65.710000    0.000000  6556.161000     27.150000    0.614000
# 25%     85.820000    4.000000  6556.599000    298.800000    0.951000
# 50%    105.940000    8.000000  6556.767000   1074.000000    1.046000
# 75%    124.710000   15.000000  6556.894000   2405.000000    1.187000
# max    144.830000   19.600000  6557.740000  30960.000000    2.609000
#
#                RV      SigmaD
# count  573.000000  265.000000
# mean  -250.085642   13.223510
# std     10.377044    8.910126
# min   -277.593319    0.882001
# 25%   -257.585228    6.827252
# 50%   -249.910892   11.067999
# 75%   -244.109459   16.887080
# max   -205.463695   46.272917

# %%
sns.distplot(dataHs.SigmaD,bins=20)
# Out:
# /home/zalenovo/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/zalenovo/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /home/zalenovo/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /home/zalenovo/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
fig, ax = plt.subplots(figsize=(14,5))
plt.scatter(dataHs.X,dataHs.Y,c=dataHs.SigmaD, s=300)
plt.axis('equal')
ax.set_xlim(65,145)
# Out:
# (65, 145)

# %%
dataHsg=(dataHs.round(2)).pivot(index='Y', columns='X', values='SigmaD')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataHsg, cmap="viridis")
plt.gca().invert_yaxis()

# %%
plt.scatter(dataHs.Peak,dataHs.SigmaD)
plt.axhline(y=10, color='k', linestyle='--')

# %% [markdown]
# [NII] Emission Line

# %%
dataN
# Out:
#            X     Y  Center.2   Peak.2  Width.2
# 41    144.83  19.6  6579.214   12.010    9.234
# 42    143.49  19.6  6581.037    9.836   11.762
# 43    142.15  19.6  6577.277   24.740    1.265
# 44    140.81  19.6  6577.335   30.080    0.953
# 45    139.46  19.6  6576.976   32.900    1.279
# ...      ...   ...       ...      ...      ...
# 1446   71.07   0.0  6577.965   87.200    1.074
# 1447   69.73   0.0  6578.028  159.500    0.743
# 1448   68.39   0.0  6577.995  167.600    0.839
# 1449   67.05   0.0  6577.959   99.180    0.867
# 1450   65.71   0.0  6577.740   32.820    1.526
#
# [600 rows x 5 columns]

# %%
sns.distplot(dataN["Peak.2"],bins=30)

# %%
fig, ax = plt.subplots(figsize=(14,5))
plt.scatter(dataN.X,dataN.Y,c=np.log10(dataN["Peak.2"]), s=300)
plt.axis('equal')
# Out:
# (61.74180558187195,
#  148.79819441812805,
#  -1.0150488574011365,
#  20.615048857401142)

# %%
#mnf=(dataN["Peak.2"]<35000)&(dataN["Peak.2"]>200)
#sns.distplot(dataN["Peak.2"],bins=30)

# %%
dataNf=(dataN.round(2)).pivot(index='Y', columns='X', values='Peak.2')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataNf, cmap="viridis")
plt.gca().invert_yaxis()

# %%
ln
# Out:
# 6583

# %% [markdown]
# #Radial velocity

# %%
RVNo=c*((dataN["Center.2"]-ln)/ln)
RVNo.describe()
# Out:
# count    600.000000
# mean    -250.630913
# std       30.938421
# min     -297.242197
# 25%     -262.324094
# 50%     -255.322258
# 75%     -247.614545
# max       14.163065
# Name: Center.2, dtype: float64

# %%
RVN=RVNo+corrhelio
RVN.describe()
# Out:
# count    600.000000
# mean    -224.950913
# std       30.938421
# min     -271.562197
# 25%     -236.644094
# 50%     -229.642258
# 75%     -221.934545
# max       39.843065
# Name: Center.2, dtype: float64

# %%
dataN=dataN.assign(RV=RVN.values)

# %%
sns.distplot(dataN.RV,bins=30)

# %%
mn=(dataN.RV<-180)&(dataN.RV>-250)
sns.distplot(dataN[mn].RV,bins=30)

# %%
dataNrv=(dataN[mn].round(2)).pivot(index='Y', columns='X', values='RV')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataNrv, cmap="viridis")
plt.gca().invert_yaxis()

# %%
sns.distplot(dataN["Width.2"],bins=30)

# %%
mns=(dataN["Width.2"]<2.5)&(dataN["Width.2"]>0)
dataN=dataN[mns]
sns.distplot(dataN["Width.2"][mns],bins=30)

# %%
dataNs=(dataN.round(2)).pivot(index='Y', columns='X', values='Width.2')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataNs, cmap="viridis")
plt.gca().invert_yaxis()

# %% [markdown]
# Sigma Disp

# %% [markdown]
# $$\frac{0.6006}{1.414}* \frac{Width}{\lambda}*c$$

# %%
SigmaObsN=a*(dataN["Width.2"]/lha)*c
SigmaObsN
# Out:
# 43      24.544714
# 44      18.490998
# 45      24.816355
# 46      25.262623
# 47      25.165608
#           ...
# 1446    20.838753
# 1447    14.416382
# 1448    16.279063
# 1449    16.822346
# 1450    29.608880
# Name: Width.2, Length: 556, dtype: float64

# %%
SigmaTermN=np.sqrt(166.3*(T/10000)/(Nw*1.414))
SigmaTermN
# Out:
# 2.6478705184531206

# %%
SigmaDispN=np.sqrt(SigmaObsN**2-SigmaTermN**2-SigmaInstN**2)
SigmaDispN.describe()
# Out:
# count    555.000000
# mean      14.875195
# std        7.086527
# min        0.561014
# 25%       10.212506
# 50%       13.134068
# 75%       17.450517
# max       44.111200
# Name: Width.2, dtype: float64

# %%
dataN=dataN.assign(SigmaD=SigmaDispN.values)
dataN.describe()
# Out:
#                 X          Y     Center.2       Peak.2     Width.2  \
# count  556.000000  556.00000   556.000000   556.000000  556.000000
# mean   104.615360    9.30036  6577.392372   356.946349    1.016191
# std     22.086867    6.22152     0.237191   449.198613    0.296842
# min     65.710000    0.00000  6576.612000    10.910000    0.577000
# 25%     85.820000    4.00000  6577.232500    81.297500    0.823000
# 50%    104.600000    8.00000  6577.381500   221.300000    0.926500
# 75%    123.370000   15.00000  6577.521250   435.825000    1.098500
# max    144.830000   19.60000  6578.451000  3893.000000    2.360000
#
#                RV      SigmaD
# count  556.000000  555.000000
# mean  -229.693613   14.875195
# std     10.801791    7.086527
# min   -265.232081    0.561014
# 25%   -236.974262   10.212506
# 50%   -230.188742   13.134068
# 75%   -223.824471   17.450517
# max   -181.483284   44.111200

# %%
sns.distplot(dataHs.SigmaD,bins=30)

# %%
fig, ax = plt.subplots(figsize=(14,5))
plt.scatter(dataN.X,dataN.Y,c=dataN.SigmaD, s=300)
plt.axis('equal')
ax.set_xlim(65,145)
# Out:
# (65, 145)

# %%
dataNsd=(dataN.round(2)).pivot(index='Y', columns='X', values='SigmaD')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataNsd, cmap="viridis")
plt.gca().invert_yaxis()

# %%
plt.scatter(dataN["Peak.2"],dataN.SigmaD)
plt.axhline(y=10, color='k', linestyle='--')

# %% [markdown]
# [SII] Emission Line

# %%
fig, ax = plt.subplots(figsize=(14,5))
plt.scatter(dataS.X,dataS.Y,c=np.log10(dataS["Peak.4"]), s=300)
plt.axis('equal')
# Out:
# /home/zalenovo/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:853: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (61.74180558187195,
#  148.79819441812805,
#  -1.0150488574011365,
#  20.615048857401142)

# %%
sns.distplot(dataS["Peak.4"],bins=30)

# %%
msf=(dataS["Peak.4"]<5000)&(dataS["Peak.4"]>0)
dataS=dataS[msf]

# %%
dataSf=(dataS.round(2)).pivot(index='Y', columns='X', values='Peak.4')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataSf, cmap="viridis")
plt.gca().invert_yaxis()

# %%
sns.distplot(dataS["Peak.4"],bins=30)

# %% [markdown]
# #Radial velocity

# %%
RVSo=c*(dataS["Center.4"]-ls)/ls
RVS=RVSo+corrhelio
RVS.describe()
# Out:
# count    587.000000
# mean    -232.950774
# std       14.719042
# min     -310.990806
# 25%     -241.109010
# 50%     -234.160916
# 75%     -227.301900
# max     -101.612653
# Name: Center.4, dtype: float64

# %%
dataS=dataS.assign(RV=RVS.values)
dataS
# Out:
#            X     Y  Center.4  Peak.4  Width.4          RV
# 41    144.83  19.6  6725.089  10.340    0.717 -237.590424
# 42    143.49  19.6  6725.229   2.199    1.365 -231.354955
# 43    142.15  19.6  6725.064  21.540    0.729 -238.703901
# 44    140.81  19.6  6724.876  12.650    0.727 -247.077245
# 45    139.46  19.6  6724.784  35.230    1.066 -251.174840
# ...      ...   ...       ...     ...      ...         ...
# 1446   71.07   0.0  6725.793  54.330    0.828 -206.234921
# 1447   69.73   0.0  6725.791  69.700    0.932 -206.323999
# 1448   68.39   0.0  6725.755  72.650    0.829 -207.927406
# 1449   67.05   0.0  6725.791  60.920    0.850 -206.323999
# 1450   65.71   0.0  6725.672  20.540    1.159 -211.624148
#
# [587 rows x 6 columns]

# %%
sns.distplot(dataS.RV,bins=30)

# %%
msrv=(dataS["RV"]<-180)&(dataS["RV"]>-300)
dataS=dataS[msrv]
sns.distplot(dataS.RV,bins=30)

# %%
fig, ax = plt.subplots(figsize=(14,5))
plt.scatter(dataS.X,dataS.Y,c=dataS.RV, s=300)
plt.axis('equal')
# Out:
# (61.74180558187195,
#  148.79819441812805,
#  -1.0150488574011365,
#  20.615048857401142)

# %%
dataSrv=(dataS.round(2)).pivot(index='Y', columns='X', values='RV')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataSrv, cmap="viridis")
plt.gca().invert_yaxis()

# %%
sns.distplot(dataS["Width.4"],bins=30)

# %%
ms=(dataS["Width.4"]<2.3)&(dataS["Width.4"]>0)
dataS=dataS[ms]
sns.distplot(dataS["Width.4"],bins=30)

# %%
fig, ax = plt.subplots(figsize=(14,5))
plt.scatter(dataS.X,dataS.Y,c=dataS["Width.4"], s=300)
plt.axis('equal')
# Out:
# (61.74180558187195,
#  148.79819441812805,
#  -1.0150488574011365,
#  20.615048857401142)

# %%
dataSw=(dataS.round(2)).pivot(index='Y', columns='X', values='Width.4')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataSw, cmap="viridis")
plt.gca().invert_yaxis()

# %%
SigmaObsS=a*(dataS["Width.4"]/ln)*c
SigmaObsS
# Out:
# 41      13.869216
# 42      26.403738
# 43      14.101337
# 44      14.062650
# 45      20.620062
#           ...
# 1446    16.016334
# 1447    18.028047
# 1448    16.035677
# 1449    16.441888
# 1450    22.418998
# Name: Width.4, Length: 562, dtype: float64

# %%
SigmaTermS=np.sqrt(166.3*(T/10000)/(Sw*1.414))
SigmaTermS
# Out:
# 1.750044272166352

# %%
SigmaDispS=np.sqrt(SigmaObsS**2-SigmaTermS**2-SigmaInstS**2)
SigmaDispS.describe()
# Out:
# count    240.000000
# mean      14.558913
# std        8.985037
# min        0.662784
# 25%        7.741244
# 50%       12.509432
# 75%       19.772176
# max       39.332340
# Name: Width.4, dtype: float64

# %%
dataS=dataS.assign(SigmaD=SigmaDispS.values)
dataS.describe()
# Out:
#                 X           Y     Center.4       Peak.4     Width.4  \
# count  562.000000  562.000000   562.000000   562.000000  562.000000
# mean   105.011263    9.422954  6725.178018   180.435884    1.037859
# std     22.486456    6.227899     0.249171   193.494753    0.300240
# min     65.710000    0.000000  6724.307000     1.154000    0.449000
# 25%     85.820000    4.000000  6725.011500    50.132500    0.839000
# 50%    104.600000    8.000000  6725.164000   126.650000    0.952000
# 75%    124.710000   15.000000  6725.315750   240.350000    1.140000
# max    144.830000   19.600000  6726.102000  1568.000000    2.260000
#
#                RV      SigmaD
# count  562.000000  240.000000
# mean  -233.625655   14.558913
# std     11.097834    8.985037
# min   -272.419974    0.662784
# 25%   -241.042202    7.741244
# 50%   -234.249994   12.509432
# 75%   -227.491191   19.772176
# max   -192.472349   39.332340

# %%
sns.distplot(SigmaDispS,bins=30)

# %%
fig, ax = plt.subplots(figsize=(14,5))
plt.scatter(dataS.X,dataS.Y,c=dataS.SigmaD, s=300)
plt.axis('equal')
ax.set_xlim(65,145)
# Out:
# (65, 145)

# %%
dataSsd=(dataS.round(2)).pivot(index='Y', columns='X', values='SigmaD')
fig, ax = plt.subplots(figsize=(17, 4))
sns.heatmap(dataSsd, cmap="viridis")
plt.gca().invert_yaxis()

# %%
plt.scatter(dataS["Peak.4"],dataS.SigmaD)
plt.axhline(y=10, color='k', linestyle='--')
